# %% [markdown]
# <a href="https://colab.research.google.com/github/Shim-John/Meltpool_Image-Prediction/blob/main/K_Fold_MPW.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install openpyxl==3.0.9
# Out:
# Requirement already satisfied: openpyxl==3.0.9 in /usr/local/lib/python3.7/dist-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl==3.0.9) (1.1.0)

# %%
# %matplotlib inline
import os
import matplotlib.pyplot as plt
import cv2
from google.colab import drive, files
import sklearn
from IPython.display import Image 
from math import sqrt
import numpy as np
from PIL import Image
import torch
import glob
import pandas as pd
import torch.nn as nn 
import torch.nn.functional as F 
from torch.utils.data import DataLoader, ConcatDataset
from torch.autograd import Variable
import torch.utils.data as Data
from torch.utils.data import Dataset
import numpy as np, imageio
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.models as models
import torchvision.transforms as transforms
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler
import time
from torch.optim.lr_scheduler import StepLR
from sklearn.model_selection import KFold
device = ("cuda" if torch.cuda.is_available() else "cpu")
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
class mpwDataset(Dataset):
    def __init__(self, root_dir, annotation_file, sheet, transform_img=None):
        self.root_dir = root_dir
        self.sheet = sheet
        self.annotations = pd.read_excel(annotation_file, sheet_name=sheet)
        self.transform_img = transform_img
        self.label = self.annotations.iloc[:, 2].tolist()

    def __len__(self):
        return len(self.annotations)

    def __getitem__(self, index):
        img_id = self.annotations.iloc[index, 0]
        img = Image.open(os.path.join(self.root_dir, img_id)).convert("RGB")
        y_label = torch.tensor(self.annotations.iloc[index, 2])
        if self.transform_img is not None:
            img = self.transform_img(img)
        return (img, y_label)

# %%
dir = '/content/drive/MyDrive/johnshim_mpd_data/image_train_v5/'
path = '/content/drive/MyDrive/johnshim_mpd_data/mpw_v4.xlsx'


transform_train = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5),
        transforms.ToTensor(),
        transforms.Normalize([0.0339, 0.0765, 0.5810],
                             [0.1614, 0.2144, 0.1777])
    ])

transform_val = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.0338, 0.0764, 0.5780],
                             [0.1612, 0.2143, 0.1773])
    ])

train_dataset = mpwDataset(dir, path, 'TRAIN', transform_img = transform_train)
val_dataset = mpwDataset(dir, path, 'TEST', transform_img = transform_val)
dataset = ConcatDataset([train_dataset, val_dataset])

mpw_max = pd.read_excel(path, sheet_name='RANGE').iloc[0, 4]
mpw_min = pd.read_excel(path, sheet_name='RANGE').iloc[0, 5]

# %%
def initialize_model(model_name, num_classes, feature_extract, use_pretrained=True):

    model_ft = None
    input_size = 0

    if model_name == "resnet":
        """ Resnet50
        """
        model_ft = models.resnet50(pretrained=use_pretrained)
        num_ftrs = model_ft.fc.in_features

        seq_model = nn.Sequential(
                  
                  nn.Linear(num_ftrs, num_classes),
                  nn.ReLU(),
                  nn.Linear(num_classes, 20),
                  nn.ReLU(),
                  nn.Linear(20, 1)
                )
        model_ft.fc = seq_model
        input_size = 224
    return model_ft, input_size
    
model_ft, input_size = initialize_model('resnet', 40, feature_extract = True, use_pretrained=True)
model_ft = model_ft.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %%
criterion = nn.L1Loss()     #Mean Absolute Error (MAE)
lr = 0.0001
num_epochs = 120

# %%
k_folds = 5
#kfold = KFold(n_splits=k_folds, shuffle=True)

kfold = KFold(n_splits=k_folds)
for fold, (train_ids, test_ids) in enumerate(kfold.split(dataset)):
    print(f'FOLD {fold}')
    print('--------------------------------')
    
    # Sample elements randomly from a given list of ids, no replacement.

    train_subsampler = torch.utils.data.SubsetRandomSampler(train_ids)
    test_subsampler = torch.utils.data.SubsetRandomSampler(test_ids)
    
    # Define data loaders for training and testing data in this fold
    trainloader = DataLoader(
                      dataset, 
                      batch_size=20, sampler=train_subsampler, pin_memory = True)
    testloader = DataLoader(
                    dataset,
                     batch_size=20, sampler=test_subsampler, pin_memory = True)   

    # Define Model
    

    model_ft, input_size = initialize_model('resnet', 40, feature_extract = True, use_pretrained=True)
    model_ft = model_ft.to(device)
    optimizer = optim.SGD(model_ft.parameters(), lr=lr, momentum=0.9)
    scheduler = StepLR(optimizer, step_size=100, gamma=0.8)

    #Train and Evaluation
    total_loss_train = []
    total_loss_val = []

    for e in range(num_epochs):
        print('Epoch {}/{}'.format(e+1, num_epochs))
        print('LR:', scheduler.get_last_lr())
        print('-' * 10)


        model_ft.train() 
        train_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.cuda(), labels.cuda()
              
            # Clear the gradients
            optimizer.zero_grad()
            # Forward Pass
            outputs = model_ft(inputs)
            labels = labels.unsqueeze(1).float()
            # Find the Loss
            loss = criterion(outputs, labels)
            # Calculate gradients 
            loss.backward()
            # Update Weights
            optimizer.step()
            # Calculate Loss
            train_loss += loss.item() * inputs.size(0)
        total_loss_train.append(train_loss / len(trainloader))

        val_loss = 0.0
        model_ft.eval()     # Optional when not using Model Specific layer
        with torch.no_grad():
          for i, data in enumerate(testloader, 0):
              # get the inputs; data is a list of [inputs, labels]
              inputs, labels = data
              inputs, labels = inputs.cuda(), labels.cuda()
                
              # Forward Pass
              outputs = model_ft(inputs)
              labels = labels.unsqueeze(1).float()
              # Find the Loss
              loss = criterion(outputs,labels)
              # Calculate Loss
              val_loss += loss.item() * inputs.size(0)
        total_loss_val.append(val_loss / len(testloader))  
        print(f'\t Training Loss: {\
        train_loss / len(testloader)} \t\t Validation Loss: {\
        val_loss / len(testloader)}')
        
        scheduler.step()    
    print('Finished Training')

    x = np.array([])
    y = np.array([])
    for (inputs, labels) in testloader:
      ## get the inputs; data is a list of [inputs, labels]
      inputs = inputs.cuda()
      labels = labels.cuda()
      output = model_ft(inputs)

      output = output.detach().cpu().numpy()
      labels = labels.detach().cpu().numpy()

      x = np.append(x,labels)
      y = np.append(y,output)
    rsquared = sklearn.metrics.r2_score(x,y)
    mse_err = sklearn.metrics.mean_squared_error(x,y)

    print('lr = ' + str(lr))
    print('rsquared = ' + str(rsquared))
    print('MSE Error = ' + str(mse_err))
# Out:
# FOLD 0
# --------------------------------
# Epoch 1/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 28.142766501592554 		 Validation Loss: 4.42490393700807
# Epoch 2/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 12.291866161901018 		 Validation Loss: 2.3615017015001047
# Epoch 3/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 6.773734352510909 		 Validation Loss: 1.4345614190982736
# Epoch 4/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 5.46636822787316 		 Validation Loss: 1.2081615918356439
# Epoch 5/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.808043175255475 		 Validation Loss: 1.0404860276890837
# Epoch 6/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 5.2032798162621 		 Validation Loss: 1.0913650950659877
# Epoch 7/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.729622265566951 		 Validation Loss: 1.0012874395950981
# Epoch 8/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.698332531620627 		 Validation Loss: 0.9015988153607949
# Epoch 9/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.788250136958516 		 Validation Loss: 1.0112298960271089
# Epoch 10/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.27651452248835 		 Validation Loss: 1.1940251420373502
# Epoch 11/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.9393898227616497 		 Validation Loss: 0.8712545069663421
# Epoch 12/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.421523956986873 		 Validation Loss: 1.0287875763100127
# Epoch 13/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.8691901214744733 		 Validation Loss: 0.9985871677813323
# Epoch 14/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.1579222488014596 		 Validation Loss: 0.9227513440925142
# Epoch 15/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.7580277683294336 		 Validation Loss: 0.9421572056801423
# Epoch 16/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.389231903721457 		 Validation Loss: 0.7619634886150775
# Epoch 17/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.890882202140663 		 Validation Loss: 0.6634234879975733
# Epoch 18/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.8200274394906084 		 Validation Loss: 0.7381182909011841
# Epoch 19/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.734740436077118 		 Validation Loss: 0.7398818724829218
# Epoch 20/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.3935930845530136 		 Validation Loss: 0.8513707635195359
# Epoch 21/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.431600144051987 		 Validation Loss: 0.6257940909784773
# Epoch 22/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.3486981354653835 		 Validation Loss: 0.6893544789889584
# Epoch 23/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.4012760064848093 		 Validation Loss: 0.7626931158744771
# Epoch 24/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.740290249009495 		 Validation Loss: 0.6014318521256032
# Epoch 25/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.324290538125712 		 Validation Loss: 0.6622657228423201
# Epoch 26/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.529446677669235 		 Validation Loss: 0.6872675454486972
# Epoch 27/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.367155997649483 		 Validation Loss: 0.695572871228923
# Epoch 28/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.0749652372754137 		 Validation Loss: 0.6782654932011729
# Epoch 29/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.226666398184455 		 Validation Loss: 0.6787381807099218
# Epoch 30/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.9619431787210964 		 Validation Loss: 0.6286371126770973
# Epoch 31/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.0717528187872274 		 Validation Loss: 0.7481242230404979
# Epoch 32/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.900513397610706 		 Validation Loss: 0.6367817472504533
# Epoch 33/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.7796618611268373 		 Validation Loss: 0.6392891899399136
# Epoch 34/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.8166269376550033 		 Validation Loss: 0.6669014319777489
# Epoch 35/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.6352411827639393 		 Validation Loss: 0.7174869529578997
# Epoch 36/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.8091734082478546 		 Validation Loss: 0.6371711971967117
# Epoch 37/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.7447544174349825 		 Validation Loss: 0.7274316380853239
# Epoch 38/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.5583302009364832 		 Validation Loss: 0.6379072562507961
# Epoch 39/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.48489822252937 		 Validation Loss: 0.6733462230666823
# Epoch 40/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.5043974050685116 		 Validation Loss: 0.5414446767257608
# Epoch 41/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.6080878542979127 		 Validation Loss: 0.6360720227593961
# Epoch 42/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.5236191170533067 		 Validation Loss: 0.6072510244405788
# Epoch 43/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.474592892210121 		 Validation Loss: 0.6097338397217833
# Epoch 44/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.2777466684903787 		 Validation Loss: 0.5601653489081756
# Epoch 45/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.322143705399788 		 Validation Loss: 0.5956260001529818
# Epoch 46/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.27170604750838 		 Validation Loss: 0.6548234787972077
# Epoch 47/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.4074724384624027 		 Validation Loss: 0.6711580426148747
# Epoch 48/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.39160290595306 		 Validation Loss: 0.5474000302669795
# Epoch 49/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1808870693911677 		 Validation Loss: 0.5947434885994248
# Epoch 50/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.129784384013518 		 Validation Loss: 0.626389920387579
# Epoch 51/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1789224131599716 		 Validation Loss: 0.5297714196469473
# Epoch 52/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.141187764785212 		 Validation Loss: 0.6909927741988845
# Epoch 53/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1838526886118497 		 Validation Loss: 0.609194469516692
# Epoch 54/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0947392678455166 		 Validation Loss: 0.6598222628235817
# Epoch 55/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9564498249117448 		 Validation Loss: 0.5492585443932078
# Epoch 56/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.000448267744935 		 Validation Loss: 0.6470284027897794
# Epoch 57/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1968372532207034 		 Validation Loss: 0.5586004621632721
# Epoch 58/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8631193243453037 		 Validation Loss: 0.5486648019565188
# Epoch 59/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9250432768755632 		 Validation Loss: 0.5669000922985699
# Epoch 60/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.897938395647899 		 Validation Loss: 0.5447246563499388
# Epoch 61/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8169213070169739 		 Validation Loss: 0.5686163124830826
# Epoch 62/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9114882766228656 		 Validation Loss: 0.5593197047710419
# Epoch 63/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9391758863854667 		 Validation Loss: 0.5437510476812072
# Epoch 64/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9047256397164387 		 Validation Loss: 0.586326825230018
# Epoch 65/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9810544603868672 		 Validation Loss: 0.55689612970404
# Epoch 66/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8922166419417963 		 Validation Loss: 0.5555071284913499
# Epoch 67/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7431003725885048 		 Validation Loss: 0.6218297309849573
# Epoch 68/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8177625068827816 		 Validation Loss: 0.5172775410439657
# Epoch 69/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7813731619845266 		 Validation Loss: 0.5718833418643993
# Epoch 70/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8462437230931676 		 Validation Loss: 0.5535269884959512
# Epoch 71/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8615129401340433 		 Validation Loss: 0.5274304812369139
# Epoch 72/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7051502024835867 		 Validation Loss: 0.5097247984098352
# Epoch 73/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7179941258028797 		 Validation Loss: 0.5232103347130443
# Epoch 74/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7456418955293687 		 Validation Loss: 0.5073620281789614
# Epoch 75/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7881077918345514 		 Validation Loss: 0.6005110219120979
# Epoch 76/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7519286031146413 		 Validation Loss: 0.539439535173385
# Epoch 77/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6460422917228679 		 Validation Loss: 0.5755358529479607
# Epoch 78/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7497615097495525 		 Validation Loss: 0.49683665127857873
# Epoch 79/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8258633374681938 		 Validation Loss: 0.6269505700987318
# Epoch 80/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7195567867273223 		 Validation Loss: 0.5088726512115934
# Epoch 81/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.663837741776977 		 Validation Loss: 0.5071893496357877
# Epoch 82/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.716676728071078 		 Validation Loss: 0.5237181209351706
# Epoch 83/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5763844188464724 		 Validation Loss: 0.48626789580220764
# Epoch 84/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7576306689854548 		 Validation Loss: 0.4828761372229327
# Epoch 85/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.709964302489939 		 Validation Loss: 0.5224047115315562
# Epoch 86/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7129846792668104 		 Validation Loss: 0.4600743171961411
# Epoch 87/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.63341836453132 		 Validation Loss: 0.49680078159207886
# Epoch 88/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6539537726051134 		 Validation Loss: 0.5985845965535744
# Epoch 89/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.480131504652293 		 Validation Loss: 0.49184108881846716
# Epoch 90/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7201894052002742 		 Validation Loss: 0.48302482732612156
# Epoch 91/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.656734511256218 		 Validation Loss: 0.5103601474800835
# Epoch 92/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4564218596028893 		 Validation Loss: 0.4925956706637922
# Epoch 93/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.443612894002834 		 Validation Loss: 0.47122697629358457
# Epoch 94/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7595458660760652 		 Validation Loss: 0.492152556291093
# Epoch 95/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6306209298579588 		 Validation Loss: 0.5287636346791101
# Epoch 96/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5791699317810328 		 Validation Loss: 0.6468925738464231
# Epoch 97/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6361777340264425 		 Validation Loss: 0.6966493262544923
# Epoch 98/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5739559016149978 		 Validation Loss: 0.5409504699966182
# Epoch 99/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5356726068193498 		 Validation Loss: 0.47921194735428563
# Epoch 100/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4679780025844988 		 Validation Loss: 0.4801350030238214
# Epoch 101/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.5983523398475803 		 Validation Loss: 0.4747610037093577
# Epoch 102/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.5451753630262355 		 Validation Loss: 0.474654845893383
# Epoch 103/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.41151616078518 		 Validation Loss: 0.4664407257476579
# Epoch 104/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.5605260528947995 		 Validation Loss: 0.519635269175405
# Epoch 105/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4844110192650037 		 Validation Loss: 0.4676882169492867
# Epoch 106/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.486104060045403 		 Validation Loss: 0.4621029588515344
# Epoch 107/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3490710660167362 		 Validation Loss: 0.46151650016722473
# Epoch 108/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.51753149635118 		 Validation Loss: 0.47685447189471
# Epoch 109/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3973548422041147 		 Validation Loss: 0.47314725087388704
# Epoch 110/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4150674547190252 		 Validation Loss: 0.5592939597756966
# Epoch 111/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4179218826896471 		 Validation Loss: 0.4962619653214579
# Epoch 112/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.5095367503716894 		 Validation Loss: 0.47471311753210815
# Epoch 113/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.5186998126623423 		 Validation Loss: 0.45758987655458244
# Epoch 114/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3437273972870216 		 Validation Loss: 0.47068357305682224
# Epoch 115/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4313714571459137 		 Validation Loss: 0.5150211683433988
# Epoch 116/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4454320844910715 		 Validation Loss: 0.4924766006677047
# Epoch 117/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.479044141328853 		 Validation Loss: 0.4900975946498954
# Epoch 118/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4213291329291204 		 Validation Loss: 0.4611571700028751
# Epoch 119/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3653754297967837 		 Validation Loss: 0.5435993749162426
# Epoch 120/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4233092965315217 		 Validation Loss: 0.49299522100583365
# Finished Training
# lr = 0.0001
# rsquared = 0.9793712272462264
# MSE Error = 0.001266838159686729
# FOLD 1
# --------------------------------
# Epoch 1/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 31.546969297787417 		 Validation Loss: 3.9671749654023545
# Epoch 2/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 10.332960443652194 		 Validation Loss: 1.6748609296653583
# Epoch 3/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 5.592522091515686 		 Validation Loss: 1.3067125593838484
# Epoch 4/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 5.089709977416889 		 Validation Loss: 1.3698408040015593
# Epoch 5/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 5.089879735170499 		 Validation Loss: 1.1457696945770928
# Epoch 6/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.726171664731658 		 Validation Loss: 0.9876193624475728
# Epoch 7/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.932091204530519 		 Validation Loss: 1.1583989405113717
# Epoch 8/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.621971477794906 		 Validation Loss: 1.4418245236510816
# Epoch 9/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.6559287614148595 		 Validation Loss: 1.0006637514933296
# Epoch 10/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.433493597999863 		 Validation Loss: 1.0074757687423541
# Epoch 11/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.636710881862951 		 Validation Loss: 0.9398728155571482
# Epoch 12/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.329576755995336 		 Validation Loss: 0.9002926621748053
# Epoch 13/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.309389925683322 		 Validation Loss: 1.230796397380207
# Epoch 14/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.357887531590203 		 Validation Loss: 0.812929454057113
# Epoch 15/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.812698786997277 		 Validation Loss: 0.7853856893337291
# Epoch 16/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.642211926372155 		 Validation Loss: 0.9021812321051307
# Epoch 17/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.06505352501636 		 Validation Loss: 0.7507732494369798
# Epoch 18/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.8126342154067494 		 Validation Loss: 0.8111608093199523
# Epoch 19/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.864658886404789 		 Validation Loss: 0.8605218500546787
# Epoch 20/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.895883055322844 		 Validation Loss: 0.6690003285589425
# Epoch 21/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.6712852041034596 		 Validation Loss: 0.8576082600199658
# Epoch 22/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.677675471681616 		 Validation Loss: 0.7007346480436947
# Epoch 23/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.458385510613089 		 Validation Loss: 0.8418009689320689
# Epoch 24/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.7816374089730824 		 Validation Loss: 0.7201165511556293
# Epoch 25/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.8746752648249916 		 Validation Loss: 0.6792904096453086
# Epoch 26/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.4272271224662014 		 Validation Loss: 0.6996280861937482
# Epoch 27/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.1919991753833448 		 Validation Loss: 0.9708514129338057
# Epoch 28/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.3888322996056597 		 Validation Loss: 0.6842213075446046
# Epoch 29/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.224240144390775 		 Validation Loss: 0.7673380718283032
# Epoch 30/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.0661654473970765 		 Validation Loss: 0.7676256820559502
# Epoch 31/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.5303406012446983 		 Validation Loss: 0.9576342190089433
# Epoch 32/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.1343618045844464 		 Validation Loss: 0.6786614769826764
# Epoch 33/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.9560769636022006 		 Validation Loss: 0.7306765635376391
# Epoch 34/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.0620839452451984 		 Validation Loss: 0.6633405929998212
# Epoch 35/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.737219701156668 		 Validation Loss: 0.7051889906110971
# Epoch 36/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.843472182588733 		 Validation Loss: 0.6755133102769437
# Epoch 37/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.7253971833573734 		 Validation Loss: 0.7333037905071093
# Epoch 38/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.2154176596390163 		 Validation Loss: 0.65581272477689
# Epoch 39/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.5597251253607483 		 Validation Loss: 0.6825008146140886
# Epoch 40/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.411326739208206 		 Validation Loss: 0.729297731557618
# Epoch 41/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.81807703897357 		 Validation Loss: 0.7293479970615843
# Epoch 42/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.4348886979986792 		 Validation Loss: 0.693454475182554
# Epoch 43/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.5977636316548223 		 Validation Loss: 0.7983998597963996
# Epoch 44/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.4051517796419235 		 Validation Loss: 0.6033077107175536
# Epoch 45/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.4452204464570335 		 Validation Loss: 0.6154939175947852
# Epoch 46/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.595345980123333 		 Validation Loss: 0.7825894929144693
# Epoch 47/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.3441739916477515 		 Validation Loss: 0.6714747651763584
# Epoch 48/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.204070001030746 		 Validation Loss: 0.5846321339840475
# Epoch 49/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.2238374742800775 		 Validation Loss: 0.6482004228493442
# Epoch 50/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1977596847016527 		 Validation Loss: 0.6638212453411974
# Epoch 51/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.171892890220751 		 Validation Loss: 0.8062528883633406
# Epoch 52/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0397652356035034 		 Validation Loss: 0.6151604101709698
# Epoch 53/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0944695994257927 		 Validation Loss: 0.6298523882161016
# Epoch 54/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0024332684343276 		 Validation Loss: 0.5648428185478501
# Epoch 55/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.120801785312917 		 Validation Loss: 0.5682378067918445
# Epoch 56/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0241166676354148 		 Validation Loss: 0.6557346475513085
# Epoch 57/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.02351197819023 		 Validation Loss: 0.5913395661374797
# Epoch 58/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0902524767038613 		 Validation Loss: 0.5648674921173117
# Epoch 59/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9687087271038606 		 Validation Loss: 0.5654125903611598
# Epoch 60/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9432126914515444 		 Validation Loss: 0.6964653957149257
# Epoch 61/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9638105636543555 		 Validation Loss: 0.5576551397857459
# Epoch 62/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8248287879092537 		 Validation Loss: 0.5894910754716914
# Epoch 63/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8521365389713775 		 Validation Loss: 0.6044436586291894
# Epoch 64/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7536232010663853 		 Validation Loss: 0.5339614625858224
# Epoch 65/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7709686733458354 		 Validation Loss: 0.5851665495530419
# Epoch 66/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.836248467311911 		 Validation Loss: 0.613116064797277
# Epoch 67/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8222263360638982 		 Validation Loss: 0.6108482214419738
# Epoch 68/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8015723118315572 		 Validation Loss: 0.5824778682511785
# Epoch 69/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7481207489643409 		 Validation Loss: 0.6415199358826098
# Epoch 70/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6454053859266897 		 Validation Loss: 0.532773833559907
# Epoch 71/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7120383614269288 		 Validation Loss: 0.6021191941007323
# Epoch 72/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8721662975199844 		 Validation Loss: 0.6588047856222028
# Epoch 73/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8301271356480278 		 Validation Loss: 0.5453355286432349
# Epoch 74/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7122688364723455 		 Validation Loss: 0.52433833722835
# Epoch 75/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6953043587829755 		 Validation Loss: 0.5592128974588021
# Epoch 76/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5081867381282474 		 Validation Loss: 0.5230107611936071
# Epoch 77/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6945873200083557 		 Validation Loss: 0.5579048702898233
# Epoch 78/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7423362689821615 		 Validation Loss: 0.5879269637491392
# Epoch 79/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6169613301753998 		 Validation Loss: 0.5199884728569052
# Epoch 80/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6474410297915987 		 Validation Loss: 0.5139126199419084
# Epoch 81/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6841332722941171 		 Validation Loss: 0.6803579725649046
# Epoch 82/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6410800525918603 		 Validation Loss: 0.5723551385428595
# Epoch 83/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5834382967618497 		 Validation Loss: 0.5431685224175453
# Epoch 84/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5405300766148644 		 Validation Loss: 0.5287503078579903
# Epoch 85/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5938456134627694 		 Validation Loss: 0.539858009180297
# Epoch 86/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6078242221442254 		 Validation Loss: 0.5680975439431875
# Epoch 87/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.619026725706847 		 Validation Loss: 0.5139016206173793
# Epoch 88/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6488405669350987 		 Validation Loss: 0.5633452680447827
# Epoch 89/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5830978512278069 		 Validation Loss: 0.5344839985279933
# Epoch 90/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6264841170252666 		 Validation Loss: 0.5410786944886913
# Epoch 91/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4584070520637475 		 Validation Loss: 0.5682541235633518
# Epoch 92/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6500507886319056 		 Validation Loss: 0.6040027883389721
# Epoch 93/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4794107922555313 		 Validation Loss: 0.524696753076885
# Epoch 94/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4482762388399113 		 Validation Loss: 0.5339132694770461
# Epoch 95/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5089588514326706 		 Validation Loss: 0.5331370040126469
# Epoch 96/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5970660114822828 		 Validation Loss: 0.5053326357965884
# Epoch 97/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5617728422031454 		 Validation Loss: 0.4827857025615547
# Epoch 98/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.500163440876033 		 Validation Loss: 0.4884302826679271
# Epoch 99/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5618838263756556 		 Validation Loss: 0.5071480313073033
# Epoch 100/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5659123785469844 		 Validation Loss: 0.5459959845504035
# Epoch 101/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3725321747200645 		 Validation Loss: 0.4896782605868319
# Epoch 102/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.5744706363538685 		 Validation Loss: 0.4926536880109621
# Epoch 103/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.5312023232488527 		 Validation Loss: 0.5266348167282083
# Epoch 104/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.5002008888303586 		 Validation Loss: 0.5096035240137059
# Epoch 105/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.5373785498187593 		 Validation Loss: 0.5223642289638519
# Epoch 106/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4916674665620793 		 Validation Loss: 0.49038779557399126
# Epoch 107/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.431324835623736 		 Validation Loss: 0.5059455675275429
# Epoch 108/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3989553067671217 		 Validation Loss: 0.4813808137955873
# Epoch 109/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4093930874748721 		 Validation Loss: 0.4811055116031481
# Epoch 110/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3865028652160063 		 Validation Loss: 0.475246741881837
# Epoch 111/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3874561912987544 		 Validation Loss: 0.48258411981489346
# Epoch 112/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3722359241674775 		 Validation Loss: 0.48437588402758475
# Epoch 113/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.488118221902329 		 Validation Loss: 0.5400936256932176
# Epoch 114/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.2929439652792138 		 Validation Loss: 0.4857556214151175
# Epoch 115/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4786704135653765 		 Validation Loss: 0.4988793340390143
# Epoch 116/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3692512784315192 		 Validation Loss: 0.48017438744073326
# Epoch 117/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3610849314085816 		 Validation Loss: 0.5560059148980223
# Epoch 118/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.2954401002548959 		 Validation Loss: 0.5016929494298022
# Epoch 119/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3487340722880934 		 Validation Loss: 0.5445041491285615
# Epoch 120/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4253864774237508 		 Validation Loss: 0.5422569074384544
# Finished Training
# lr = 0.0001
# rsquared = 0.9733610734394468
# MSE Error = 0.0014838264215235447
# FOLD 2
# --------------------------------
# Epoch 1/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 27.74516821685045 		 Validation Loss: 5.125170053995174
# Epoch 2/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 19.452643097742744 		 Validation Loss: 4.1000605478234915
# Epoch 3/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 14.577546652244484 		 Validation Loss: 2.752968035314394
# Epoch 4/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 8.552583897243375 		 Validation Loss: 1.6303623700919359
# Epoch 5/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 5.842231959752414 		 Validation Loss: 1.9555214523621227
# Epoch 6/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.962986505549887 		 Validation Loss: 1.063767540714015
# Epoch 7/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.718258683124314 		 Validation Loss: 0.9098223632444506
# Epoch 8/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.215836301122023 		 Validation Loss: 0.9440797593282617
# Epoch 9/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.201222649411015 		 Validation Loss: 0.8164090821924417
# Epoch 10/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.056179887250714 		 Validation Loss: 0.9003600322681925
# Epoch 11/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.8544419106581937 		 Validation Loss: 0.8041348126919373
# Epoch 12/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.879244697158751 		 Validation Loss: 0.7993845503939234
# Epoch 13/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.752836692430403 		 Validation Loss: 0.7774380586393501
# Epoch 14/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.708239308517912 		 Validation Loss: 0.8218501747950263
# Epoch 15/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.5678064852305083 		 Validation Loss: 0.7700747873472131
# Epoch 16/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.5960038843686166 		 Validation Loss: 0.7051066814557366
# Epoch 17/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.35898289181616 		 Validation Loss: 0.772629390106253
# Epoch 18/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.5599261739331745 		 Validation Loss: 0.8162173536484656
# Epoch 19/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.2360823687327946 		 Validation Loss: 0.6996821426665005
# Epoch 20/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.2044617585513904 		 Validation Loss: 0.771620129113612
# Epoch 21/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.8901765903700953 		 Validation Loss: 0.7366931608513646
# Epoch 22/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.162920815141305 		 Validation Loss: 0.7124739946878474
# Epoch 23/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.1451413605524148 		 Validation Loss: 0.6777886687575475
# Epoch 24/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.9894545586860697 		 Validation Loss: 0.7241826368414838
# Epoch 25/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.9149420565885045 		 Validation Loss: 0.6786565565220688
# Epoch 26/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.793581924036793 		 Validation Loss: 0.6723665663891513
# Epoch 27/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.7863913403581018 		 Validation Loss: 0.6702516124300335
# Epoch 28/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.678941313015378 		 Validation Loss: 0.6637751469793527
# Epoch 29/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.547712097025436 		 Validation Loss: 0.7473743467227273
# Epoch 30/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.716283262423847 		 Validation Loss: 0.6286783476724572
# Epoch 31/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.4969553490695744 		 Validation Loss: 0.6536039300262928
# Epoch 32/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.569208323793567 		 Validation Loss: 0.7436290640869866
# Epoch 33/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.586451995955861 		 Validation Loss: 0.6210588590930337
# Epoch 34/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.2917803618247095 		 Validation Loss: 0.6339871316500332
# Epoch 35/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.4762224103121655 		 Validation Loss: 0.783977385610342
# Epoch 36/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.3058615801450997 		 Validation Loss: 0.7166720763982638
# Epoch 37/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.391873277723789 		 Validation Loss: 0.6319367673410021
# Epoch 38/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.3231789233243982 		 Validation Loss: 0.6186769377116276
# Epoch 39/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.348867367953062 		 Validation Loss: 0.6857919133389774
# Epoch 40/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.189117850816768 		 Validation Loss: 0.5897973843080841
# Epoch 41/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1144440812261207 		 Validation Loss: 0.6013319372482921
# Epoch 42/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.260831428124853 		 Validation Loss: 0.5894062791181647
# Epoch 43/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.224875761762909 		 Validation Loss: 0.6030368754721206
# Epoch 44/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.2400255094727743 		 Validation Loss: 0.5691635759304399
# Epoch 45/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.271188670202442 		 Validation Loss: 0.570120293242128
# Epoch 46/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.083439746628637 		 Validation Loss: 0.6411730216249175
# Epoch 47/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0807989285044046 		 Validation Loss: 0.5856634699132132
# Epoch 48/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1771937767448635 		 Validation Loss: 0.651598578237969
# Epoch 49/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.937240381117748 		 Validation Loss: 0.6411639720039524
# Epoch 50/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9097047216542389 		 Validation Loss: 0.663046596976726
# Epoch 51/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.223286718777988 		 Validation Loss: 0.6237573103736276
# Epoch 52/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8559535455120646 		 Validation Loss: 0.5524775564022686
# Epoch 53/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9182442831604376 		 Validation Loss: 0.6504347546269065
# Epoch 54/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9670876347176407 		 Validation Loss: 0.6185799634650998
# Epoch 55/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.885383197956759 		 Validation Loss: 0.5596523464697859
# Epoch 56/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.881995195603889 		 Validation Loss: 0.5855411034401344
# Epoch 57/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.835430761070355 		 Validation Loss: 0.5465386960169544
# Epoch 58/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8355137935799102 		 Validation Loss: 0.5205308189210684
# Epoch 59/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8033928918125837 		 Validation Loss: 0.5457765942682391
# Epoch 60/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8091691230302271 		 Validation Loss: 0.49263293773907685
# Epoch 61/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9199825977177725 		 Validation Loss: 0.6909980582802192
# Epoch 62/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8861643166645714 		 Validation Loss: 0.5648166729218286
# Epoch 63/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8775197364713834 		 Validation Loss: 0.526606870977127
# Epoch 64/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7119066663410352 		 Validation Loss: 0.508360541790076
# Epoch 65/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8025491742984108 		 Validation Loss: 0.4969709554444189
# Epoch 66/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6998957742167555 		 Validation Loss: 0.4851178512301134
# Epoch 67/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.821445664309937 		 Validation Loss: 0.5462432997706144
# Epoch 68/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7380075508161732 		 Validation Loss: 0.6113818244117758
# Epoch 69/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7400624765002208 		 Validation Loss: 0.4882034075486919
# Epoch 70/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.755216902202886 		 Validation Loss: 0.5114233268667823
# Epoch 71/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7728713268171186 		 Validation Loss: 0.6537465718777283
# Epoch 72/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.741368425767059 		 Validation Loss: 0.5194825762477906
# Epoch 73/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7300795771019615 		 Validation Loss: 0.5679068085939988
# Epoch 74/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.702304372968881 		 Validation Loss: 0.5321559340733549
# Epoch 75/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6875262164875218 		 Validation Loss: 0.49374992983496707
# Epoch 76/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6362684761052546 		 Validation Loss: 0.49698440528110316
# Epoch 77/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6181475953401432 		 Validation Loss: 0.4988705252661653
# Epoch 78/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6358327415326368 		 Validation Loss: 0.4799428603247456
# Epoch 79/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5181601701871208 		 Validation Loss: 0.527221231356911
# Epoch 80/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6666775230804216 		 Validation Loss: 0.49732158373555413
# Epoch 81/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5282451277193816 		 Validation Loss: 0.48833371747447096
# Epoch 82/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6563356828106486 		 Validation Loss: 0.6638101319903913
# Epoch 83/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6608779835312262 		 Validation Loss: 0.48751217037763284
# Epoch 84/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6378678148207457 		 Validation Loss: 0.5152313233879597
# Epoch 85/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5217446064495521 		 Validation Loss: 0.4792138278160406
# Epoch 86/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5444286352266436 		 Validation Loss: 0.5718028645800508
# Epoch 87/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5730533878440442 		 Validation Loss: 0.5073951555658942
# Epoch 88/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5750613582684942 		 Validation Loss: 0.48965328121962753
# Epoch 89/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.593317671476499 		 Validation Loss: 0.4725148175721583
# Epoch 90/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.598008625695239 		 Validation Loss: 0.5330307995495589
# Epoch 91/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4759364997887092 		 Validation Loss: 0.45826473402912205
# Epoch 92/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5341557976182387 		 Validation Loss: 0.47802786164633604
# Epoch 93/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4836074008565883 		 Validation Loss: 0.5261372996737128
# Epoch 94/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5485124172561842 		 Validation Loss: 0.5077895124483368
# Epoch 95/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4588153418153524 		 Validation Loss: 0.47896491922438145
# Epoch 96/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5211529368939607 		 Validation Loss: 0.515025536408243
# Epoch 97/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5056355143694773 		 Validation Loss: 0.48462598041995714
# Epoch 98/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4491650421658289 		 Validation Loss: 0.5004849130206782
# Epoch 99/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5204795207828283 		 Validation Loss: 0.5621646883209115
# Epoch 100/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5540957713256711 		 Validation Loss: 0.48444632149260974
# Epoch 101/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3708614112566346 		 Validation Loss: 0.4208223143106569
# Epoch 102/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3950799565114405 		 Validation Loss: 0.5174764352648155
# Epoch 103/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4383067730814219 		 Validation Loss: 0.4806780070066452
# Epoch 104/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.414128738414982 		 Validation Loss: 0.4643234761998705
# Epoch 105/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3891580582636853 		 Validation Loss: 0.452389749576864
# Epoch 106/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.405380001210648 		 Validation Loss: 0.42957475935311423
# Epoch 107/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3520632080895745 		 Validation Loss: 0.46004879296473833
# Epoch 108/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3525689931019493 		 Validation Loss: 0.48025272908094135
# Epoch 109/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4379698063206414 		 Validation Loss: 0.45190115256801894
# Epoch 110/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3896090219850126 		 Validation Loss: 0.48145650424387143
# Epoch 111/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4445126819545808 		 Validation Loss: 0.4595936990302542
# Epoch 112/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4857998638535324 		 Validation Loss: 0.43060765172476356
# Epoch 113/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.405069888771876 		 Validation Loss: 0.4485324244622303
# Epoch 114/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3195248612243196 		 Validation Loss: 0.4561900765351627
# Epoch 115/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3001332376962123 		 Validation Loss: 0.4517933085722768
# Epoch 116/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3423413913292082 		 Validation Loss: 0.44963048123147176
# Epoch 117/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3255179071717935 		 Validation Loss: 0.47156760817312676
# Epoch 118/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3872125927844774 		 Validation Loss: 0.4327920006345148
# Epoch 119/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4120869336082884 		 Validation Loss: 0.4721999227514733
# Epoch 120/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4102935342361098 		 Validation Loss: 0.5109906373140605
# Finished Training
# lr = 0.0001
# rsquared = 0.9799105854943254
# MSE Error = 0.0011200500739552434
# FOLD 3
# --------------------------------
# Epoch 1/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 19.05521610962308 		 Validation Loss: 1.5301275803990986
# Epoch 2/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 5.900395891588667 		 Validation Loss: 1.3476441149478373
# Epoch 3/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 5.265101531601471 		 Validation Loss: 1.888260007876417
# Epoch 4/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 5.087231000156506 		 Validation Loss: 1.0630649355766566
# Epoch 5/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.9957418480645055 		 Validation Loss: 0.909683100555254
# Epoch 6/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.6795078943605 		 Validation Loss: 0.9166245604662792
# Epoch 7/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.667039092144241 		 Validation Loss: 0.9182113366930381
# Epoch 8/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.355182749745638 		 Validation Loss: 1.2391545255870924
# Epoch 9/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.299395595879658 		 Validation Loss: 1.6209926773672518
# Epoch 10/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.625835329294205 		 Validation Loss: 0.9269420741044957
# Epoch 11/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.659138083781885 		 Validation Loss: 1.1518342827001344
# Epoch 12/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.225006269372028 		 Validation Loss: 0.8469790100403454
# Epoch 13/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.108993853887786 		 Validation Loss: 0.9216190231559069
# Epoch 14/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.227870637631935 		 Validation Loss: 0.8483607137332791
# Epoch 15/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.013685406874055 		 Validation Loss: 0.8244019814807436
# Epoch 16/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.9516302593376325 		 Validation Loss: 0.729786373026993
# Epoch 17/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.615767644637304 		 Validation Loss: 0.7200052656395279
# Epoch 18/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.8401097049531727 		 Validation Loss: 0.741858715272468
# Epoch 19/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.7033914742262466 		 Validation Loss: 0.7748633471682019
# Epoch 20/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.8933515321949255 		 Validation Loss: 0.6760257396685041
# Epoch 21/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.736214647312527 		 Validation Loss: 1.1056924520627311
# Epoch 22/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.0843575480191605 		 Validation Loss: 0.791164256632328
# Epoch 23/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.761108521534049 		 Validation Loss: 1.0258052328034588
# Epoch 24/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.5808380424328474 		 Validation Loss: 0.7799120811016663
# Epoch 25/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.4439811552672284 		 Validation Loss: 0.6314121415919584
# Epoch 26/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.751782513830973 		 Validation Loss: 0.655332425042339
# Epoch 27/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.899466607881629 		 Validation Loss: 0.6384033985112024
# Epoch 28/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.6826855935480283 		 Validation Loss: 0.7335346844047308
# Epoch 29/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.4782258876315924 		 Validation Loss: 0.6083712295993514
# Epoch 30/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.6029433608055115 		 Validation Loss: 1.7316649018422416
# Epoch 31/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.2110661736325077 		 Validation Loss: 0.7458835587553356
# Epoch 32/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.3008758448388265 		 Validation Loss: 0.8912488321733215
# Epoch 33/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.2013257720872113 		 Validation Loss: 0.6417585561132949
# Epoch 34/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.196363679902709 		 Validation Loss: 0.7784912759519141
# Epoch 35/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.151514889429445 		 Validation Loss: 0.5734719009665044
# Epoch 36/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.9547309857671675 		 Validation Loss: 0.6351651062622018
# Epoch 37/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.982256169876327 		 Validation Loss: 0.6456998761581338
# Epoch 38/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.3620596273761727 		 Validation Loss: 0.5835495434053566
# Epoch 39/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.7858089548738105 		 Validation Loss: 0.6835131472705499
# Epoch 40/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.9120190265062065 		 Validation Loss: 0.7335226046650306
# Epoch 41/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.843511417184187 		 Validation Loss: 0.57314941610979
# Epoch 42/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.079881314026273 		 Validation Loss: 0.5729479652060114
# Epoch 43/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.5060249439076236 		 Validation Loss: 0.5270221309493417
# Epoch 44/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.9838584748947103 		 Validation Loss: 0.6932447889576787
# Epoch 45/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.4954293535455414 		 Validation Loss: 0.7189624763053396
# Epoch 46/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.3880315698359325 		 Validation Loss: 0.5693081257783849
# Epoch 47/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.629060513947321 		 Validation Loss: 0.6266595133296822
# Epoch 48/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.586889428936917 		 Validation Loss: 0.5522351051964189
# Epoch 49/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.8376811835105005 		 Validation Loss: 0.5629847012460232
# Epoch 50/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.454885144758484 		 Validation Loss: 0.5882727535360533
# Epoch 51/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.3085861745411935 		 Validation Loss: 0.6665230884176233
# Epoch 52/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.460802364122608 		 Validation Loss: 0.9762859106387781
# Epoch 53/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.436084446537754 		 Validation Loss: 0.5651524403820867
# Epoch 54/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.341680422587239 		 Validation Loss: 0.5102470691275337
# Epoch 55/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1634439743407397 		 Validation Loss: 0.849284306978402
# Epoch 56/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.4831770890108915 		 Validation Loss: 0.6573029879642569
# Epoch 57/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1018080194683177 		 Validation Loss: 0.5150489798220603
# Epoch 58/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.2043777746350868 		 Validation Loss: 0.7266624718904495
# Epoch 59/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1369339085143544 		 Validation Loss: 0.5722199412791625
# Epoch 60/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0855888714608937 		 Validation Loss: 0.7004996713088907
# Epoch 61/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0150877663298794 		 Validation Loss: 0.543948981910944
# Epoch 62/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0979280608665682 		 Validation Loss: 0.5309796939077585
# Epoch 63/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9237389515923418 		 Validation Loss: 0.5131826881805192
# Epoch 64/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9372988540841185 		 Validation Loss: 0.5301762918091338
# Epoch 65/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.914885401725769 		 Validation Loss: 0.5547175634166469
# Epoch 66/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.038709494082824 		 Validation Loss: 0.6477396844521813
# Epoch 67/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9891630326924117 		 Validation Loss: 0.502223001954996
# Epoch 68/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.928353334898534 		 Validation Loss: 0.49228389901311503
# Epoch 69/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9596464331059351 		 Validation Loss: 0.5665180842675592
# Epoch 70/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.018221338320038 		 Validation Loss: 0.6247720039733078
# Epoch 71/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9168901383552863 		 Validation Loss: 0.4920223112339559
# Epoch 72/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9211474389809629 		 Validation Loss: 0.5026192249649245
# Epoch 73/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.832689151653777 		 Validation Loss: 0.49786617129069305
# Epoch 74/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7817685032344384 		 Validation Loss: 0.48327300794746564
# Epoch 75/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7856210839489233 		 Validation Loss: 0.5447141567812018
# Epoch 76/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6994281250821508 		 Validation Loss: 0.5076153317223424
# Epoch 77/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6739219057009271 		 Validation Loss: 0.5284791785575773
# Epoch 78/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7831450427841882 		 Validation Loss: 0.5620564865353315
# Epoch 79/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8781855652189774 		 Validation Loss: 0.5044060181016508
# Epoch 80/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8115142617860567 		 Validation Loss: 0.5637647010709929
# Epoch 81/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7277767596685367 		 Validation Loss: 0.47326012360660924
# Epoch 82/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7060079101635062 		 Validation Loss: 0.6430413146381793
# Epoch 83/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8062282935108827 		 Validation Loss: 0.5355301811967207
# Epoch 84/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6696273470702379 		 Validation Loss: 0.4935962422548429
# Epoch 85/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8060777143615743 		 Validation Loss: 0.4866616782610831
# Epoch 86/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6731651831904184 		 Validation Loss: 0.4754588005497404
# Epoch 87/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7024684938723627 		 Validation Loss: 0.4514952413737774
# Epoch 88/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6558439653852712 		 Validation Loss: 0.5414802250654801
# Epoch 89/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6696371102462644 		 Validation Loss: 0.4393354036399852
# Epoch 90/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.659223794127288 		 Validation Loss: 0.48590813220843027
# Epoch 91/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6973730344325304 		 Validation Loss: 0.4519689784425756
# Epoch 92/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6603422610332137 		 Validation Loss: 0.46833239811594074
# Epoch 93/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6230080114758534 		 Validation Loss: 0.48508612544316315
# Epoch 94/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.534614270714962 		 Validation Loss: 0.4497801058156335
# Epoch 95/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6040085055257962 		 Validation Loss: 0.46383877495384734
# Epoch 96/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6101858018209105 		 Validation Loss: 0.4711841276806334
# Epoch 97/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6738225407898426 		 Validation Loss: 0.4840924058757398
# Epoch 98/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6371129976342553 		 Validation Loss: 0.48363611474633217
# Epoch 99/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5782892467535061 		 Validation Loss: 0.4488466880891634
# Epoch 100/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5328589094721752 		 Validation Loss: 0.4548229181572147
# Epoch 101/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.503134841747258 		 Validation Loss: 0.44829862532408343
# Epoch 102/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.5440249745936498 		 Validation Loss: 0.5017342860607997
# Epoch 103/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.549162327757348 		 Validation Loss: 0.4340224577842847
# Epoch 104/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.5395453538259734 		 Validation Loss: 0.43850669175710366
# Epoch 105/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4446986006653828 		 Validation Loss: 0.4340522878843805
# Epoch 106/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.5985680522154206 		 Validation Loss: 0.4363210859667996
# Epoch 107/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.507181696674746 		 Validation Loss: 0.4333939961279216
# Epoch 108/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.563907188322881 		 Validation Loss: 0.474283328441822
# Epoch 109/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.6198788815704377 		 Validation Loss: 0.46003049887392833
# Epoch 110/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4269359566919182 		 Validation Loss: 0.4340161555649146
# Epoch 111/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.5484661929633305 		 Validation Loss: 0.4507298910909373
# Epoch 112/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4423244895170564 		 Validation Loss: 0.4435493009488868
# Epoch 113/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4818043558979812 		 Validation Loss: 0.44290612637996674
# Epoch 114/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.5452307600366033 		 Validation Loss: 0.4517972708234321
# Epoch 115/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4720525360139816 		 Validation Loss: 0.4187629350015651
# Epoch 116/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4478859086723432 		 Validation Loss: 0.4624482443475205
# Epoch 117/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4154528162401656 		 Validation Loss: 0.45328378758352733
# Epoch 118/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.5709866502362748 		 Validation Loss: 0.46536403732455295
# Epoch 119/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.3947017630157263 		 Validation Loss: 0.4718196166112371
# Epoch 120/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.4143433232346307 		 Validation Loss: 0.4472610073407059
# Finished Training
# lr = 0.0001
# rsquared = 0.9770200707067641
# MSE Error = 0.0013575551468518652
# FOLD 4
# --------------------------------
# Epoch 1/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 45.411103994950004 		 Validation Loss: 7.846024593581324
# Epoch 2/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 19.905250570048455 		 Validation Loss: 2.7041278397259503
# Epoch 3/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 7.6400997237018915 		 Validation Loss: 1.3502007504196272
# Epoch 4/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 5.404818935562735 		 Validation Loss: 1.0312181288457436
# Epoch 5/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 5.004465290385744 		 Validation Loss: 0.9785552420046019
# Epoch 6/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 5.062231756746769 		 Validation Loss: 0.8532599262569261
# Epoch 7/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 5.164698155677837 		 Validation Loss: 1.4042104997712632
# Epoch 8/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.765307847248471 		 Validation Loss: 1.593669985299525
# Epoch 9/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.539945806174175 		 Validation Loss: 0.7933892403607783
# Epoch 10/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.906035385054091 		 Validation Loss: 1.2879672727507094
# Epoch 11/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.283686412741309 		 Validation Loss: 0.7982189665022104
# Epoch 12/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.477728511652221 		 Validation Loss: 0.8857178781991419
# Epoch 13/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.469714923883262 		 Validation Loss: 1.1908225375025168
# Epoch 14/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.281038265189399 		 Validation Loss: 1.2823204288016194
# Epoch 15/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.067131386502929 		 Validation Loss: 0.7501140951138475
# Epoch 16/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.044405920350033 		 Validation Loss: 0.7924621753070665
# Epoch 17/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.9861326157722785 		 Validation Loss: 0.744318836733051
# Epoch 18/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.805578503595746 		 Validation Loss: 0.8021120921425198
# Epoch 19/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.217981286022974 		 Validation Loss: 0.9879535318392775
# Epoch 20/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.0663386806845665 		 Validation Loss: 0.7641104880882346
# Epoch 21/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.764487765405489 		 Validation Loss: 0.8032944213760935
# Epoch 22/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.047901840313621 		 Validation Loss: 0.6697700643992942
# Epoch 23/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.6850242041375325 		 Validation Loss: 0.720285083450701
# Epoch 24/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.908273594049008 		 Validation Loss: 0.908201508871887
# Epoch 25/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.395244950833528 		 Validation Loss: 0.6523673286580521
# Epoch 26/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.3933450958651044 		 Validation Loss: 0.6773426906894082
# Epoch 27/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.3555630330482256 		 Validation Loss: 0.7419851961667123
# Epoch 28/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.2535450993024786 		 Validation Loss: 0.6575925183360991
# Epoch 29/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.1718776209846786 		 Validation Loss: 0.6888141189904317
# Epoch 30/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.1015718942103176 		 Validation Loss: 0.7856164296036181
# Epoch 31/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.0779814425369967 		 Validation Loss: 0.7678228696079358
# Epoch 32/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.2364461898155836 		 Validation Loss: 1.2059381911936013
# Epoch 33/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.016708553809187 		 Validation Loss: 0.6091315351102663
# Epoch 34/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.961429140490034 		 Validation Loss: 0.6225913803538551
# Epoch 35/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.7010416522946046 		 Validation Loss: 0.6263647653648386
# Epoch 36/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.795820945468934 		 Validation Loss: 0.6214721329186274
# Epoch 37/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.7999285695993383 		 Validation Loss: 0.7253340541020684
# Epoch 38/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.754413200461346 		 Validation Loss: 0.6235749532023201
# Epoch 39/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.44438478982319 		 Validation Loss: 0.6351688167323237
# Epoch 40/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.455925464792096 		 Validation Loss: 0.7198451193778411
# Epoch 41/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.624677843697693 		 Validation Loss: 0.5855165004082348
# Epoch 42/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.714774557267842 		 Validation Loss: 0.5599602214668108
# Epoch 43/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.4588739943245184 		 Validation Loss: 0.6251668751887653
# Epoch 44/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.400663470282503 		 Validation Loss: 0.5793902818923411
# Epoch 45/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.272105120284402 		 Validation Loss: 0.6960113912658847
# Epoch 46/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.318343090136414 		 Validation Loss: 0.6602670688020147
# Epoch 47/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.2163485670867176 		 Validation Loss: 0.5324921168224968
# Epoch 48/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.266407290554565 		 Validation Loss: 0.5801889813788559
# Epoch 49/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.2592058065144913 		 Validation Loss: 0.6532655311343463
# Epoch 50/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.151502523571253 		 Validation Loss: 0.5298046550672987
# Epoch 51/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.123863551603711 		 Validation Loss: 0.5146071469492238
# Epoch 52/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1404500271639098 		 Validation Loss: 0.5992083900972552
# Epoch 53/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.111564312778089 		 Validation Loss: 0.5356507335344086
# Epoch 54/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0607590566834677 		 Validation Loss: 0.5834259553609983
# Epoch 55/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.20805026995747 		 Validation Loss: 0.5347597450827775
# Epoch 56/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.061785327837519 		 Validation Loss: 0.5653787924219733
# Epoch 57/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.082546747573044 		 Validation Loss: 0.5186788700520992
# Epoch 58/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.065691693969395 		 Validation Loss: 0.5483037754083457
# Epoch 59/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.023011167574188 		 Validation Loss: 0.6400996023870033
# Epoch 60/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0779123249585214 		 Validation Loss: 0.5367184275680262
# Epoch 61/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9716000257302886 		 Validation Loss: 0.5181112320202849
# Epoch 62/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9261092274733211 		 Validation Loss: 0.5084507141424262
# Epoch 63/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9952198323672232 		 Validation Loss: 0.5821430989257668
# Epoch 64/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9054750668937745 		 Validation Loss: 0.5432444429429977
# Epoch 65/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.924495039102824 		 Validation Loss: 0.5322752207841562
# Epoch 66/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9588758091887701 		 Validation Loss: 0.5331714306350636
# Epoch 67/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8787683988718882 		 Validation Loss: 0.49525609701547935
# Epoch 68/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.830741137266159 		 Validation Loss: 0.5411794771156881
# Epoch 69/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7994095744646115 		 Validation Loss: 0.6690532650960528
# Epoch 70/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8435241993030775 		 Validation Loss: 0.5204408732445344
# Epoch 71/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7982978914742884 		 Validation Loss: 0.5203310742002466
# Epoch 72/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8034582977061686 		 Validation Loss: 0.6223782471016698
# Epoch 73/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7442022353086784 		 Validation Loss: 0.5386809524472641
# Epoch 74/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7940252237021923 		 Validation Loss: 0.6460645307341347
# Epoch 75/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7890716042855512 		 Validation Loss: 0.6427525541866603
# Epoch 76/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7442719377577305 		 Validation Loss: 0.6532995942980051
# Epoch 77/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7747343657133372 		 Validation Loss: 0.5842797683308953
# Epoch 78/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6705024870841398 		 Validation Loss: 0.48604457857816113
# Epoch 79/120
# LR: [0.0001]
# ----------
