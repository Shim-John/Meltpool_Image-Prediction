# %% [markdown]
# <a href="https://colab.research.google.com/github/Shim-John/Meltpool_Image-Prediction/blob/main/K_Fold_MPD.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
pip install openpyxl==3.0.9
# Out:
# Requirement already satisfied: openpyxl==3.0.9 in /usr/local/lib/python3.7/dist-packages (3.0.9)
# Requirement already satisfied: et-xmlfile in /usr/local/lib/python3.7/dist-packages (from openpyxl==3.0.9) (1.1.0)

# %%
# %matplotlib inline
import os
import matplotlib.pyplot as plt
import cv2
from google.colab import drive, files
import sklearn
from IPython.display import Image 
from math import sqrt
import numpy as np
from PIL import Image
import torch
import glob
import pandas as pd
import torch.nn as nn 
import torch.nn.functional as F 
from torch.utils.data import DataLoader, ConcatDataset
from torch.autograd import Variable
import torch.utils.data as Data
from torch.utils.data import Dataset
import numpy as np, imageio
import torch.optim as optim
import torchvision
import torchvision.datasets as datasets
import torchvision.models as models
import torchvision.transforms as transforms
from sklearn.metrics import r2_score
from sklearn.preprocessing import MinMaxScaler
import time
from torch.optim.lr_scheduler import StepLR
from sklearn.model_selection import KFold
device = ("cuda" if torch.cuda.is_available() else "cpu")
drive.mount('/content/drive/')
# Out:
# Mounted at /content/drive/

# %%
class mpwDataset(Dataset):
    def __init__(self, root_dir, annotation_file, sheet, transform_img=None):
        self.root_dir = root_dir
        self.sheet = sheet
        self.annotations = pd.read_excel(annotation_file, sheet_name=sheet)
        self.transform_img = transform_img
        self.label = self.annotations.iloc[:, 2].tolist()

    def __len__(self):
        return len(self.annotations)

    def __getitem__(self, index):
        img_id = self.annotations.iloc[index, 0]
        img = Image.open(os.path.join(self.root_dir, img_id)).convert("RGB")
        y_label = torch.tensor(self.annotations.iloc[index, 2])
        if self.transform_img is not None:
            img = self.transform_img(img)
        return (img, y_label)

# %%
dir = '/content/drive/MyDrive/johnshim_mpd_data/image_train_v5/'
path = '/content/drive/MyDrive/johnshim_mpd_data/mpd.xlsx'


transform_train = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.RandomHorizontalFlip(p=0.5),
        transforms.RandomVerticalFlip(p=0.5),
        transforms.ToTensor(),
        transforms.Normalize([0.0339, 0.0765, 0.5810],
                             [0.1614, 0.2144, 0.1777])
    ])

transform_val = transforms.Compose([
        transforms.Resize(256),
        transforms.CenterCrop(224),
        transforms.ToTensor(),
        transforms.Normalize([0.0338, 0.0764, 0.5780],
                             [0.1612, 0.2143, 0.1773])
    ])

train_dataset = mpwDataset(dir, path, 'TRAIN', transform_img = transform_train)
val_dataset = mpwDataset(dir, path, 'TEST', transform_img = transform_val)
dataset = ConcatDataset([train_dataset, val_dataset])

mpd_max = pd.read_excel(path, sheet_name='RANGE').iloc[0, 4]
mpd_min = pd.read_excel(path, sheet_name='RANGE').iloc[0, 5]

# %%
def initialize_model(model_name, num_classes, feature_extract, use_pretrained=True):

    model_ft = None
    input_size = 0

    if model_name == "resnet":
        """ Resnet50
        """
        model_ft = models.resnet50(pretrained=use_pretrained)
        num_ftrs = model_ft.fc.in_features

        seq_model = nn.Sequential(
                  
                  nn.Linear(num_ftrs, num_classes),
                  nn.ReLU(),
                  nn.Linear(num_classes, 20),
                  nn.ReLU(),
                  nn.Linear(20, 1)
                )
        model_ft.fc = seq_model
        input_size = 224
    return model_ft, input_size
    
model_ft, input_size = initialize_model('resnet', 40, feature_extract = True, use_pretrained=True)
model_ft = model_ft.to(device)
# Out:
# Downloading: "https://download.pytorch.org/models/resnet50-0676ba61.pth" to /root/.cache/torch/hub/checkpoints/resnet50-0676ba61.pth
#   0%|          | 0.00/97.8M [00:00<?, ?B/s]

# %% [markdown]
# ### Hyperparameters

# %%
criterion = nn.L1Loss()     #Mean Absolute Error (MAE)
lr = 0.0001
num_epochs = 120

# %%
k_folds = 5
#kfold = KFold(n_splits=k_folds, shuffle=True)

kfold = KFold(n_splits=k_folds)
for fold, (train_ids, test_ids) in enumerate(kfold.split(dataset)):
    print(f'FOLD {fold}')
    print('--------------------------------')
    
    # Sample elements randomly from a given list of ids, no replacement.

    train_subsampler = torch.utils.data.SubsetRandomSampler(train_ids)
    test_subsampler = torch.utils.data.SubsetRandomSampler(test_ids)
    
    # Define data loaders for training and testing data in this fold
    trainloader = DataLoader(
                      dataset, 
                      batch_size=20, sampler=train_subsampler, pin_memory = True)
    testloader = DataLoader(
                    dataset,
                     batch_size=20, sampler=test_subsampler, pin_memory = True)   

    # Define Model
    

    model_ft, input_size = initialize_model('resnet', 40, feature_extract = True, use_pretrained=True)
    model_ft = model_ft.to(device)
    optimizer = optim.SGD(model_ft.parameters(), lr=lr, momentum=0.9)
    scheduler = StepLR(optimizer, step_size=100, gamma=0.8)

    #Train and Evaluation
    total_loss_train = []
    total_loss_val = []

    for e in range(num_epochs):
        print('Epoch {}/{}'.format(e+1, num_epochs))
        print('LR:', scheduler.get_last_lr())
        print('-' * 10)


        model_ft.train() 
        train_loss = 0.0
        for i, data in enumerate(trainloader, 0):
            # get the inputs; data is a list of [inputs, labels]
            inputs, labels = data
            inputs, labels = inputs.cuda(), labels.cuda()
              
            # Clear the gradients
            optimizer.zero_grad()
            # Forward Pass
            outputs = model_ft(inputs)
            labels = labels.unsqueeze(1).float()
            # Find the Loss
            loss = criterion(outputs, labels)
            # Calculate gradients 
            loss.backward()
            # Update Weights
            optimizer.step()
            # Calculate Loss
            train_loss += loss.item() * inputs.size(0)
        total_loss_train.append(train_loss / len(trainloader))

        val_loss = 0.0
        model_ft.eval()     # Optional when not using Model Specific layer
        with torch.no_grad():
          for i, data in enumerate(testloader, 0):
              # get the inputs; data is a list of [inputs, labels]
              inputs, labels = data
              inputs, labels = inputs.cuda(), labels.cuda()
                
              # Forward Pass
              outputs = model_ft(inputs)
              labels = labels.unsqueeze(1).float()
              # Find the Loss
              loss = criterion(outputs,labels)
              # Calculate Loss
              val_loss += loss.item() * inputs.size(0)
        total_loss_val.append(val_loss / len(testloader))  
        print(f'\t Training Loss: {\
        train_loss / len(testloader)} \t\t Validation Loss: {\
        val_loss / len(testloader)}')
        
        scheduler.step()    
    print('Finished Training')

    x = np.array([])
    y = np.array([])
    for (inputs, labels) in testloader:
      ## get the inputs; data is a list of [inputs, labels]
      inputs = inputs.cuda()
      labels = labels.cuda()
      output = model_ft(inputs)

      output = output.detach().cpu().numpy()
      labels = labels.detach().cpu().numpy()

      x = np.append(x,labels)
      y = np.append(y,output)
    rsquared = sklearn.metrics.r2_score(x,y)
    mse_err = sklearn.metrics.mean_squared_error(x,y)

    print('lr = ' + str(lr))
    print('rsquared = ' + str(rsquared))
    print('MSE Error = ' + str(mse_err))
# Out:
# FOLD 0
# --------------------------------
# Epoch 1/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 24.799797628236853 		 Validation Loss: 2.5830928592578224
# Epoch 2/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 6.913257343613583 		 Validation Loss: 1.208244719259117
# Epoch 3/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.51859032654244 		 Validation Loss: 1.2049789694340334
# Epoch 4/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.058436945080757 		 Validation Loss: 0.814689179153546
# Epoch 5/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.7425628777431403 		 Validation Loss: 0.8871647067691969
# Epoch 6/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.617624678041624 		 Validation Loss: 0.7629747073287549
# Epoch 7/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.5426707222409872 		 Validation Loss: 0.6872681107210077
# Epoch 8/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.346423494103162 		 Validation Loss: 0.6247089932794156
# Epoch 9/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.8881652165690195 		 Validation Loss: 0.6927680483330851
# Epoch 10/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.190997485557328 		 Validation Loss: 0.5739252625600152
# Epoch 11/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.977920312920342 		 Validation Loss: 0.6668035977560541
# Epoch 12/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.0303321173009663 		 Validation Loss: 0.5755607864778974
# Epoch 13/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.00181165450941 		 Validation Loss: 0.5287481326123943
# Epoch 14/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.812116608509551 		 Validation Loss: 0.6569099766404732
# Epoch 15/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.147342335594737 		 Validation Loss: 0.5495705941449041
# Epoch 16/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.6311882186843003 		 Validation Loss: 0.5559816592089508
# Epoch 17/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.017126034135404 		 Validation Loss: 0.7506071095881255
# Epoch 18/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.958208734250587 		 Validation Loss: 0.5115867470917494
# Epoch 19/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.00410851172131 		 Validation Loss: 1.017423960501733
# Epoch 20/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.9171334589305133 		 Validation Loss: 0.7778629271880441
# Epoch 21/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.6147095977288224 		 Validation Loss: 0.5027473240118959
# Epoch 22/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.053290104250545 		 Validation Loss: 0.4791218706447145
# Epoch 23/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.661990705229666 		 Validation Loss: 0.4641052683734376
# Epoch 24/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.5807775587815307 		 Validation Loss: 0.4541788906182932
# Epoch 25/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.847350085073191 		 Validation Loss: 0.5141655104639737
# Epoch 26/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.683951979422051 		 Validation Loss: 0.5660184440405472
# Epoch 27/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.778692605540804 		 Validation Loss: 0.5042790030331715
# Epoch 28/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.498838847907989 		 Validation Loss: 0.4416433009116546
# Epoch 29/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.3764271120662275 		 Validation Loss: 0.43964286780227785
# Epoch 30/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.5979213095877483 		 Validation Loss: 0.458011520297631
# Epoch 31/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.540050944880299 		 Validation Loss: 0.5553917716378751
# Epoch 32/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.248322986876187 		 Validation Loss: 0.45463807233001874
# Epoch 33/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.377848003545533 		 Validation Loss: 0.43131737605385156
# Epoch 34/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.587373538185721 		 Validation Loss: 0.45001047784867493
# Epoch 35/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.479864331043285 		 Validation Loss: 0.40055675675039704
# Epoch 36/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.2163663257075394 		 Validation Loss: 0.41160255751532054
# Epoch 37/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.4049266757362564 		 Validation Loss: 0.41289986151715985
# Epoch 38/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.3443929023392824 		 Validation Loss: 0.42973557406145596
# Epoch 39/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1826383983311444 		 Validation Loss: 0.44756307064191153
# Epoch 40/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.105636653692826 		 Validation Loss: 0.42239395820576214
# Epoch 41/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0260064196975334 		 Validation Loss: 0.41757443028947583
# Epoch 42/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1063670963048935 		 Validation Loss: 0.45824580137496407
# Epoch 43/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.004808863543946 		 Validation Loss: 0.3996211079799611
# Epoch 44/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1179254136007764 		 Validation Loss: 0.38340517117277434
# Epoch 45/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1521513334111027 		 Validation Loss: 0.3675071077178354
# Epoch 46/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.068133437196198 		 Validation Loss: 0.40325657181117847
# Epoch 47/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.037963351315778 		 Validation Loss: 0.3937956666492898
# Epoch 48/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9262069641895916 		 Validation Loss: 0.3698074679983699
# Epoch 49/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9049721341580153 		 Validation Loss: 0.3504439662008182
# Epoch 50/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9197618656832238 		 Validation Loss: 0.367494340500106
# Epoch 51/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.850476601201555 		 Validation Loss: 0.3943931999737802
# Epoch 52/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9477697601136954 		 Validation Loss: 0.3572070493322352
# Epoch 53/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9155780072121515 		 Validation Loss: 0.3785863291958104
# Epoch 54/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8762478261538174 		 Validation Loss: 0.4113695511351461
# Epoch 55/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8545094986000787 		 Validation Loss: 0.3683489399111789
# Epoch 56/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7876877753954867 		 Validation Loss: 0.40165269342453586
# Epoch 57/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.941511991555276 		 Validation Loss: 0.3748967474245507
# Epoch 58/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0888891974868984 		 Validation Loss: 0.37570263785512553
# Epoch 59/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8229194983192112 		 Validation Loss: 0.39261920053673827
# Epoch 60/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8270281397778054 		 Validation Loss: 0.359004945696696
# Epoch 61/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7423720999580363 		 Validation Loss: 0.3702005322860635
# Epoch 62/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.684557803299116 		 Validation Loss: 0.3610373094030049
# Epoch 63/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7928585682226263 		 Validation Loss: 0.3464472212869188
# Epoch 64/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.833078257901513 		 Validation Loss: 0.38659604023332184
# Epoch 65/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.644002935970607 		 Validation Loss: 0.34029471971418546
# Epoch 66/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5933937261933866 		 Validation Loss: 0.4038536216577758
# Epoch 67/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6102641176270402 		 Validation Loss: 0.3434843561895516
# Epoch 68/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.778704445809126 		 Validation Loss: 0.40825123048346973
# Epoch 69/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6770825207881306 		 Validation Loss: 0.36340497677092964
# Epoch 70/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.676222769462544 		 Validation Loss: 0.4356266817320948
# Epoch 71/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.762502987342684 		 Validation Loss: 0.44391797693527263
# Epoch 72/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6965839644165144 		 Validation Loss: 0.3390604727294134
# Epoch 73/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.488301382035665 		 Validation Loss: 0.3074950570969478
# Epoch 74/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.545763055510495 		 Validation Loss: 0.3366144592671291
# Epoch 75/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.503607185314531 		 Validation Loss: 0.3109305594926295
# Epoch 76/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6782041654476654 		 Validation Loss: 0.33209674384282983
# Epoch 77/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5449517212160255 		 Validation Loss: 0.3670610463165719
# Epoch 78/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4910425202030202 		 Validation Loss: 0.3214164110629455
# Epoch 79/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.519636614005203 		 Validation Loss: 0.32074739265701047
# Epoch 80/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.536992873834527 		 Validation Loss: 0.32549835822504497
# Epoch 81/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5263317292151244 		 Validation Loss: 0.34236252226907277
# Epoch 82/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.507797312801299 		 Validation Loss: 0.3502380410614221
# Epoch 83/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4873184572257425 		 Validation Loss: 0.3219209481840548
# Epoch 84/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4308530983879515 		 Validation Loss: 0.3370866592487563
# Epoch 85/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.429392752683033 		 Validation Loss: 0.3228718447296516
# Epoch 86/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3726637751349937 		 Validation Loss: 0.30262881646985595
# Epoch 87/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2605837857269722 		 Validation Loss: 0.3157242355139359
# Epoch 88/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4316919202227956 		 Validation Loss: 0.39417805636058684
# Epoch 89/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4657778526939775 		 Validation Loss: 0.3121905506629011
# Epoch 90/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4112728965347228 		 Validation Loss: 0.4356051382163297
# Epoch 91/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3946976157958093 		 Validation Loss: 0.2953091802318459
# Epoch 92/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3249544498065244 		 Validation Loss: 0.32729000420026155
# Epoch 93/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3214341470890718 		 Validation Loss: 0.3121106350875419
# Epoch 94/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3274682389329309 		 Validation Loss: 0.3357455336853214
# Epoch 95/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3404380179455746 		 Validation Loss: 0.3194347347902215
# Epoch 96/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.349795632145327 		 Validation Loss: 0.3372994445912216
# Epoch 97/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3338294546727254 		 Validation Loss: 0.30548536907071655
# Epoch 98/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.311977718187415 		 Validation Loss: 0.30531666282078496
# Epoch 99/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.163996128284413 		 Validation Loss: 0.3093018524510705
# Epoch 100/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2289406832145608 		 Validation Loss: 0.30840947454714257
# Epoch 101/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.2696313084629567 		 Validation Loss: 0.2822355917938378
# Epoch 102/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.2747794873202625 		 Validation Loss: 0.27790351446879946
# Epoch 103/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1726057330227417 		 Validation Loss: 0.3019580981977608
# Epoch 104/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.2059119623964247 		 Validation Loss: 0.28662967374143394
# Epoch 105/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1936418724286815 		 Validation Loss: 0.2906792942920457
# Epoch 106/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1522156407489725 		 Validation Loss: 0.28861282474320865
# Epoch 107/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1758010742133078 		 Validation Loss: 0.33234280979503755
# Epoch 108/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.2019930173359488 		 Validation Loss: 0.3097249421736468
# Epoch 109/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1967588325395533 		 Validation Loss: 0.29112141255451285
# Epoch 110/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1664713156288085 		 Validation Loss: 0.29183359654701274
# Epoch 111/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.2658897694200277 		 Validation Loss: 0.29554115284396254
# Epoch 112/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1533249603665394 		 Validation Loss: 0.3711243864634763
# Epoch 113/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1719079020878542 		 Validation Loss: 0.33757255048207613
# Epoch 114/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.136309359708558 		 Validation Loss: 0.36157358194822853
# Epoch 115/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1614612522332564 		 Validation Loss: 0.3239917552665524
# Epoch 116/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.2115173401392025 		 Validation Loss: 0.27440808227528696
# Epoch 117/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.055747099949614 		 Validation Loss: 0.285972415915002
# Epoch 118/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0352486418155225 		 Validation Loss: 0.2680996497688086
# Epoch 119/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.240122545591515 		 Validation Loss: 0.29009502786009206
# Epoch 120/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1387499582994243 		 Validation Loss: 0.2859623697788819
# Finished Training
# lr = 0.0001
# rsquared = 0.9805241750358713
# MSE Error = 0.00047591350913126434
# FOLD 1
# --------------------------------
# Epoch 1/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 33.671437815479614 		 Validation Loss: 3.4529099127520686
# Epoch 2/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 7.05566983346058 		 Validation Loss: 1.1796037383053615
# Epoch 3/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.223084456570771 		 Validation Loss: 1.275756478957508
# Epoch 4/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.035660283073135 		 Validation Loss: 1.329375913609629
# Epoch 5/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.6888306137660276 		 Validation Loss: 0.9128038844336634
# Epoch 6/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.488341596139514 		 Validation Loss: 1.477244570851326
# Epoch 7/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.4771044783942076 		 Validation Loss: 0.8778799454803052
# Epoch 8/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.128708676475546 		 Validation Loss: 0.7678428502834361
# Epoch 9/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.264800760895014 		 Validation Loss: 0.658205000926619
# Epoch 10/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.01246478797301 		 Validation Loss: 0.8750201583556507
# Epoch 11/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.0664266249083956 		 Validation Loss: 0.8177765070096307
# Epoch 12/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.8018351074146186 		 Validation Loss: 0.6945462476300157
# Epoch 13/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.635085622253625 		 Validation Loss: 0.8563876038660174
# Epoch 14/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.8213816239782004 		 Validation Loss: 0.7192405070299688
# Epoch 15/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.768054356555576 		 Validation Loss: 0.5524160194656124
# Epoch 16/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.7162753605972165 		 Validation Loss: 0.6154659293268038
# Epoch 17/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.637705675447765 		 Validation Loss: 0.5566549835645634
# Epoch 18/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.635081646559031 		 Validation Loss: 0.5986476657183274
# Epoch 19/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.492543240280255 		 Validation Loss: 0.6224313605090847
# Epoch 20/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.58768619434989 		 Validation Loss: 0.5894185958997064
# Epoch 21/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.486213622695726 		 Validation Loss: 0.5377720668911934
# Epoch 22/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.3291073341084565 		 Validation Loss: 0.5018647573888302
# Epoch 23/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.310334727006114 		 Validation Loss: 0.6081908730709035
# Epoch 24/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.2757299364261003 		 Validation Loss: 0.7733607826673466
# Epoch 25/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.061130479140126 		 Validation Loss: 0.4553963324945906
# Epoch 26/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.3804246650441834 		 Validation Loss: 0.6496325086640276
# Epoch 27/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9467296710480815 		 Validation Loss: 0.8550930444313132
# Epoch 28/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0625440231321948 		 Validation Loss: 0.5347986503139787
# Epoch 29/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.160438069668801 		 Validation Loss: 0.461048188254885
# Epoch 30/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9651533940240093 		 Validation Loss: 0.44660488548486127
# Epoch 31/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.814490093647138 		 Validation Loss: 0.48867308818127797
# Epoch 32/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.073913514452136 		 Validation Loss: 0.5573570971255717
# Epoch 33/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9121838740032653 		 Validation Loss: 0.4622464586535226
# Epoch 34/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7865381399574487 		 Validation Loss: 0.5154377230159615
# Epoch 35/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.928897165733835 		 Validation Loss: 0.4976235046658827
# Epoch 36/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8806663947584836 		 Validation Loss: 0.45854076176233916
# Epoch 37/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6877018890303115 		 Validation Loss: 0.5652671193946963
# Epoch 38/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.720959611237049 		 Validation Loss: 0.43665462294998375
# Epoch 39/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.734524636974801 		 Validation Loss: 0.4244067617084669
# Epoch 40/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6898665862238926 		 Validation Loss: 0.481533445417881
# Epoch 41/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.634482941225819 		 Validation Loss: 0.743229763339395
# Epoch 42/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6097557662945727 		 Validation Loss: 0.5689504969379177
# Epoch 43/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6240633160847684 		 Validation Loss: 0.44718801975250244
# Epoch 44/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6320579827803632 		 Validation Loss: 0.6112365667586741
# Epoch 45/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.623362325941739 		 Validation Loss: 0.5455329998031907
# Epoch 46/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5307146625026413 		 Validation Loss: 0.4740257310154645
# Epoch 47/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5059797279536724 		 Validation Loss: 0.42544455550934956
# Epoch 48/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5070049788640894 		 Validation Loss: 0.5282684771910958
# Epoch 49/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4325239771734113 		 Validation Loss: 0.4432829874365226
# Epoch 50/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5254408841871696 		 Validation Loss: 0.7782958480327026
# Epoch 51/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5075349947032721 		 Validation Loss: 0.40924344616739644
# Epoch 52/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5607940859120826 		 Validation Loss: 0.4276863914792952
# Epoch 53/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5344294259405655 		 Validation Loss: 0.5518385395407677
# Epoch 54/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.456079881152381 		 Validation Loss: 0.41909307079470676
# Epoch 55/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4665820477125437 		 Validation Loss: 0.46979858013598813
# Epoch 56/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4152972075440313 		 Validation Loss: 0.4097214430246664
# Epoch 57/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.396314108096387 		 Validation Loss: 0.5547115109536959
# Epoch 58/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3815197853128547 		 Validation Loss: 0.42568288905465085
# Epoch 59/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.299484266049188 		 Validation Loss: 0.45770725397312123
# Epoch 60/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3435451338148636 		 Validation Loss: 0.3836048491623091
# Epoch 61/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3443565215591504 		 Validation Loss: 0.4148783972081931
# Epoch 62/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.254428655071103 		 Validation Loss: 0.3930218469189561
# Epoch 63/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2886001050634228 		 Validation Loss: 0.43564004742580914
# Epoch 64/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.331230519987319 		 Validation Loss: 0.4697506064954011
# Epoch 65/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2875084642968748 		 Validation Loss: 0.45797936618328094
# Epoch 66/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3095463510278775 		 Validation Loss: 0.5350890885228696
# Epoch 67/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3150072224924099 		 Validation Loss: 0.4412388323765734
# Epoch 68/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3033705694681925 		 Validation Loss: 0.36669945992205455
# Epoch 69/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2821254224071037 		 Validation Loss: 0.4050548253176005
# Epoch 70/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.185667427499657 		 Validation Loss: 0.41560433966958005
# Epoch 71/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2846291382675585 		 Validation Loss: 0.36742925400967186
# Epoch 72/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2293354160273853 		 Validation Loss: 0.4614222681392794
# Epoch 73/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2576313773575036 		 Validation Loss: 0.37876237588732137
# Epoch 74/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.184551552100026 		 Validation Loss: 0.3598127052511858
# Epoch 75/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1537352275589239 		 Validation Loss: 0.35093684478298476
# Epoch 76/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1947792829216823 		 Validation Loss: 0.34846847876906395
# Epoch 77/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.159115226696367 		 Validation Loss: 0.3718316158198792
# Epoch 78/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1865307011682054 		 Validation Loss: 0.3842656913658847
# Epoch 79/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1634941380470991 		 Validation Loss: 0.34268351757655974
# Epoch 80/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1263759343520454 		 Validation Loss: 0.36550394542839215
# Epoch 81/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3811978543906107 		 Validation Loss: 0.4291199050519777
# Epoch 82/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.180054960448457 		 Validation Loss: 0.4592671520684076
# Epoch 83/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1748424617816573 		 Validation Loss: 0.356591348738774
# Epoch 84/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1558209396898746 		 Validation Loss: 0.35767593623503396
# Epoch 85/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2502701341619957 		 Validation Loss: 0.4277695051353911
# Epoch 86/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1187715811411971 		 Validation Loss: 0.363187289432339
# Epoch 87/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1522769348128983 		 Validation Loss: 0.33547574087329535
# Epoch 88/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1993816318395345 		 Validation Loss: 0.39671108288609463
# Epoch 89/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.078593816689175 		 Validation Loss: 0.3609972374270792
# Epoch 90/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.0776945785011933 		 Validation Loss: 0.3558456290351308
# Epoch 91/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.098016946617028 		 Validation Loss: 0.3510552207412927
# Epoch 92/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1717983182195737 		 Validation Loss: 0.4328329853065636
# Epoch 93/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.092782382974806 		 Validation Loss: 0.36626081184848497
# Epoch 94/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2650973988777918 		 Validation Loss: 0.3258305496495703
# Epoch 95/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2024733390983031 		 Validation Loss: 0.40488779787784035
# Epoch 96/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.0361662327271441 		 Validation Loss: 0.39900446958515956
# Epoch 97/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.0918646878360405 		 Validation Loss: 0.3388344188747199
# Epoch 98/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.092129194137195 		 Validation Loss: 0.39647443948880484
# Epoch 99/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.021971818788544 		 Validation Loss: 0.34457644285715144
# Epoch 100/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 0.9810994346018719 		 Validation Loss: 0.355760325556216
# Epoch 101/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0753560136679723 		 Validation Loss: 0.4123310971519221
# Epoch 102/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0637159394505231 		 Validation Loss: 0.309680646042461
# Epoch 103/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0969335298337366 		 Validation Loss: 0.3339992010075113
# Epoch 104/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 0.9671986508790565 		 Validation Loss: 0.335373623377603
# Epoch 105/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0032966703824375 		 Validation Loss: 0.3187435460479363
# Epoch 106/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0846734724371978 		 Validation Loss: 0.36769534582677094
# Epoch 107/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0369784098280512 		 Validation Loss: 0.31647548727367236
# Epoch 108/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 0.9416763024485629 		 Validation Loss: 0.415059982434563
# Epoch 109/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0402341351398956 		 Validation Loss: 0.5883222624011661
# Epoch 110/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 0.9429426781185295 		 Validation Loss: 0.35873664057125215
# Epoch 111/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 0.9213542103281488 		 Validation Loss: 0.32717706149686937
# Epoch 112/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.004211545476447 		 Validation Loss: 0.3310141032156737
# Epoch 113/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 0.9696058306195166 		 Validation Loss: 0.35472232605452125
# Epoch 114/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0225116247716157 		 Validation Loss: 0.36638867757890536
# Epoch 115/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0330880046214745 		 Validation Loss: 0.3867705911397934
# Epoch 116/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 0.9882739049423 		 Validation Loss: 0.30568753126198833
# Epoch 117/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0030370917495177 		 Validation Loss: 0.3223557972713657
# Epoch 118/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 0.9433280351855184 		 Validation Loss: 0.37636170001781505
# Epoch 119/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 0.9315320289005404 		 Validation Loss: 0.31393575279609015
# Epoch 120/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 0.9660545500886181 		 Validation Loss: 0.3349444780336774
# Finished Training
# lr = 0.0001
# rsquared = 0.9666732166784532
# MSE Error = 0.0009414774890149018
# FOLD 2
# --------------------------------
# Epoch 1/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 17.416605685068212 		 Validation Loss: 2.188535617745441
# Epoch 2/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 6.369083536707836 		 Validation Loss: 1.3836086249869803
# Epoch 3/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.750377585706503 		 Validation Loss: 0.912325665678667
# Epoch 4/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.135933366158734 		 Validation Loss: 1.592407450079918
# Epoch 5/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.4828808531165123 		 Validation Loss: 0.6858879619318506
# Epoch 6/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.309901661199072 		 Validation Loss: 0.6870164997551752
# Epoch 7/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.2195671140823676 		 Validation Loss: 0.9897577406271644
# Epoch 8/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.281112898789022 		 Validation Loss: 1.2828075723803563
# Epoch 9/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.983124886517939 		 Validation Loss: 0.5524931621292363
# Epoch 10/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.0979749168390813 		 Validation Loss: 0.8617793622872104
# Epoch 11/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.883185546035352 		 Validation Loss: 0.504460189005603
# Epoch 12/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.0446770265698433 		 Validation Loss: 0.5331434973556063
# Epoch 13/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.1891927608977193 		 Validation Loss: 0.6037515450430953
# Epoch 14/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.7773270500094993 		 Validation Loss: 0.7043279917991679
# Epoch 15/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.1274630430599917 		 Validation Loss: 0.8108779318306757
# Epoch 16/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.7333439928681953 		 Validation Loss: 0.546547956764698
# Epoch 17/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.757196021468743 		 Validation Loss: 0.4646237793823947
# Epoch 18/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.670048574714557 		 Validation Loss: 0.4574580361013827
# Epoch 19/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.5346456126350425 		 Validation Loss: 0.6241311780784441
# Epoch 20/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.5242753587663174 		 Validation Loss: 0.4625208036083242
# Epoch 21/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.4470263925259528 		 Validation Loss: 0.45619165524840355
# Epoch 22/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.6023054728689403 		 Validation Loss: 0.47489690877821134
# Epoch 23/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.396574353232332 		 Validation Loss: 0.4865519718631454
# Epoch 24/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.4157250944686974 		 Validation Loss: 0.4642665864008924
# Epoch 25/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.4939426814570376 		 Validation Loss: 0.5226005889151407
# Epoch 26/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.447017406963784 		 Validation Loss: 0.41227904188892117
# Epoch 27/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.400911997517814 		 Validation Loss: 0.464076882471209
# Epoch 28/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.4581697716013244 		 Validation Loss: 0.5051204384021137
# Epoch 29/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.3623626213520765 		 Validation Loss: 0.49212400841972104
# Epoch 30/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.285737440475951 		 Validation Loss: 0.3905932993992515
# Epoch 31/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.21927244540142 		 Validation Loss: 0.44157301521171693
# Epoch 32/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0600497050453788 		 Validation Loss: 0.4557957111493401
# Epoch 33/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.497050600450324 		 Validation Loss: 0.7071813228337661
# Epoch 34/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1337493295254917 		 Validation Loss: 0.548499322131924
# Epoch 35/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.2985187135636806 		 Validation Loss: 0.5636855976089187
# Epoch 36/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.225425419114206 		 Validation Loss: 0.4232205312861049
# Epoch 37/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9584748449370912 		 Validation Loss: 0.47594751514818356
# Epoch 38/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9441040039224469 		 Validation Loss: 0.3945492791092914
# Epoch 39/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0383392653387524 		 Validation Loss: 0.3731858001455017
# Epoch 40/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9661076601756655 		 Validation Loss: 0.5368731170892715
# Epoch 41/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.143530808389187 		 Validation Loss: 0.3896866301479547
# Epoch 42/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8224745679484762 		 Validation Loss: 0.37622440606355667
# Epoch 43/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7945764892451141 		 Validation Loss: 0.45298672564651654
# Epoch 44/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8105499004216299 		 Validation Loss: 0.4375445980416692
# Epoch 45/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0969047970745875 		 Validation Loss: 0.41132081057066505
# Epoch 46/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8788379320631856 		 Validation Loss: 0.3545732326481653
# Epoch 47/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8039329775973507 		 Validation Loss: 0.3820809422303801
# Epoch 48/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7564296178195788 		 Validation Loss: 0.4182374550272589
# Epoch 49/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8122506316589273 		 Validation Loss: 0.4140163836595805
# Epoch 50/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6656088000568359 		 Validation Loss: 0.4139357027800187
# Epoch 51/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6874637006903472 		 Validation Loss: 0.3670319307433522
# Epoch 52/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6494926086262516 		 Validation Loss: 0.3881737800396007
# Epoch 53/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6691017667560473 		 Validation Loss: 0.37405118832121725
# Epoch 54/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5880735359438087 		 Validation Loss: 0.3594988600715347
# Epoch 55/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5004395589880322 		 Validation Loss: 0.35870983629770903
# Epoch 56/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.449763977981132 		 Validation Loss: 0.48494188681892725
# Epoch 57/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3835813409608344 		 Validation Loss: 0.37909567761032475
# Epoch 58/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.420604204111125 		 Validation Loss: 0.4046376899856588
# Epoch 59/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5523163931363302 		 Validation Loss: 0.3442048832126286
# Epoch 60/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4915767511271911 		 Validation Loss: 0.38485427103612735
# Epoch 61/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4643031845436147 		 Validation Loss: 0.36286516762945964
# Epoch 62/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4266723604953808 		 Validation Loss: 0.35534649844402855
# Epoch 63/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4867079562467078 		 Validation Loss: 0.3614097064279992
# Epoch 64/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4146396444867486 		 Validation Loss: 0.397245186664488
# Epoch 65/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4148548935418543 		 Validation Loss: 0.36337084096411
# Epoch 66/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3245588453567547 		 Validation Loss: 0.34707071826509805
# Epoch 67/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.347878986807621 		 Validation Loss: 0.33627852959477383
# Epoch 68/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4667463369019653 		 Validation Loss: 0.3822243699560995
# Epoch 69/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3174722564771124 		 Validation Loss: 0.3268483329726302
# Epoch 70/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3582079323899487 		 Validation Loss: 0.3123009731264218
# Epoch 71/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.276763115645103 		 Validation Loss: 0.35449156051744585
# Epoch 72/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3495595845515314 		 Validation Loss: 0.3244842985725921
# Epoch 73/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3228855451326007 		 Validation Loss: 0.3145822380547938
# Epoch 74/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2418440813603608 		 Validation Loss: 0.3721909200691659
# Epoch 75/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.312969211165024 		 Validation Loss: 0.32485137491122534
# Epoch 76/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2552538522235726 		 Validation Loss: 0.34861879828183545
# Epoch 77/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.223498481447282 		 Validation Loss: 0.31625065142693726
# Epoch 78/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.248530209955314 		 Validation Loss: 0.37910915506274806
# Epoch 79/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2442115954244914 		 Validation Loss: 0.3566056498042915
# Epoch 80/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1777143035407946 		 Validation Loss: 0.32461488052554754
# Epoch 81/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.251706023498074 		 Validation Loss: 0.3131738620931688
# Epoch 82/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1567937328439692 		 Validation Loss: 0.3547265340128671
# Epoch 83/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1841655715328196 		 Validation Loss: 0.31649611647362297
# Epoch 84/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.238337769375547 		 Validation Loss: 0.35200033336877823
# Epoch 85/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2933739370302013 		 Validation Loss: 0.30512887255653093
# Epoch 86/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1797305448385684 		 Validation Loss: 0.29092878589163657
# Epoch 87/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1568408292596755 		 Validation Loss: 0.3166944274435873
# Epoch 88/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1901980914661419 		 Validation Loss: 0.295801121417595
# Epoch 89/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1374209668973219 		 Validation Loss: 0.3233772783499697
# Epoch 90/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1972897006603687 		 Validation Loss: 0.37977398980570876
# Epoch 91/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.0808453440018322 		 Validation Loss: 0.32650770862465317
# Epoch 92/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1503257536045883 		 Validation Loss: 0.3687446766897388
# Epoch 93/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1125248208156098 		 Validation Loss: 0.3424946777522564
# Epoch 94/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.0977852806934845 		 Validation Loss: 0.33898280933499336
# Epoch 95/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2388023383429516 		 Validation Loss: 0.33406365095921187
# Epoch 96/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1336390284578437 		 Validation Loss: 0.32378100911560265
# Epoch 97/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1195753909971402 		 Validation Loss: 0.28882617454813875
# Epoch 98/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1239100847717212 		 Validation Loss: 0.32076017931103706
# Epoch 99/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1676592574171398 		 Validation Loss: 0.38345855539259704
# Epoch 100/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1396702076915814 		 Validation Loss: 0.3046562474059022
# Epoch 101/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0951605208380066 		 Validation Loss: 0.28078332057465677
# Epoch 102/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0584004343203877 		 Validation Loss: 0.2863970188343007
# Epoch 103/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.170980589059384 		 Validation Loss: 0.2838626649716626
# Epoch 104/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0056362821842018 		 Validation Loss: 0.27386960533002147
# Epoch 105/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.04182035913286 		 Validation Loss: 0.2929408722759589
# Epoch 106/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0645616502379593 		 Validation Loss: 0.29265890059911687
# Epoch 107/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0353666556108256 		 Validation Loss: 0.29192715397347574
# Epoch 108/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.027255910165284 		 Validation Loss: 0.2939937919702219
# Epoch 109/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1198286283761263 		 Validation Loss: 0.2910474890276142
# Epoch 110/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0773619903332514 		 Validation Loss: 0.2995651377284009
# Epoch 111/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0683238658568133 		 Validation Loss: 0.28021880061082216
# Epoch 112/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0169590670291497 		 Validation Loss: 0.29599448665976524
# Epoch 113/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0087384813181732 		 Validation Loss: 0.2874413545688857
# Epoch 114/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 0.9887390593471734 		 Validation Loss: 0.2584204158705214
# Epoch 115/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0035518167297477 		 Validation Loss: 0.2728202841852022
# Epoch 116/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0323388242041287 		 Validation Loss: 0.26336497343752696
# Epoch 117/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0451789273192054 		 Validation Loss: 0.27483848368991975
# Epoch 118/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.00590209144613 		 Validation Loss: 0.2669289764826712
# Epoch 119/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 0.9767333198662685 		 Validation Loss: 0.2772850786214289
# Epoch 120/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 0.9857859851225562 		 Validation Loss: 0.2930507051717976
# Finished Training
# lr = 0.0001
# rsquared = 0.9822366664050478
# MSE Error = 0.00045058285884875344
# FOLD 3
# --------------------------------
# Epoch 1/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 10.30694679543376 		 Validation Loss: 1.0599451719418815
# Epoch 2/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.449252836730169 		 Validation Loss: 1.199724825989941
# Epoch 3/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.8904815619082553 		 Validation Loss: 0.7531708359070446
# Epoch 4/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.636395640185346 		 Validation Loss: 0.6572155341829943
# Epoch 5/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.6291865333914757 		 Validation Loss: 0.9409004569701527
# Epoch 6/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.478498364758232 		 Validation Loss: 0.6979142461457978
# Epoch 7/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.609477131910946 		 Validation Loss: 0.6837076643562835
# Epoch 8/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.1152675315413787 		 Validation Loss: 0.6846541602002538
# Epoch 9/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.24220810474261 		 Validation Loss: 0.6958179090010084
# Epoch 10/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.183051362147798 		 Validation Loss: 1.111331017282994
# Epoch 11/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.2862427997524324 		 Validation Loss: 0.6128472944964534
# Epoch 12/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.1919556595385075 		 Validation Loss: 0.5535264727861985
# Epoch 13/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.1667423419978307 		 Validation Loss: 0.9338609218273474
# Epoch 14/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.9241593999221274 		 Validation Loss: 0.5333713301174019
# Epoch 15/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.895551974520735 		 Validation Loss: 0.48654196087432944
# Epoch 16/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.8031363378724325 		 Validation Loss: 0.5138946048429479
# Epoch 17/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.9370887070570304 		 Validation Loss: 0.7774601871876613
# Epoch 18/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.9638638466434633 		 Validation Loss: 0.6465656751685817
# Epoch 19/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.8633895233759414 		 Validation Loss: 0.4771874554293311
# Epoch 20/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.5077743230630523 		 Validation Loss: 0.6121306825105263
# Epoch 21/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.7657362791183204 		 Validation Loss: 0.5195697529808335
# Epoch 22/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.6495609178977166 		 Validation Loss: 0.4585295450752196
# Epoch 23/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.9352927603151486 		 Validation Loss: 0.5528271990301816
# Epoch 24/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.3954790982863177 		 Validation Loss: 0.4074261039495468
# Epoch 25/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.6845669451615084 		 Validation Loss: 0.48493230302372703
# Epoch 26/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.712940743435984 		 Validation Loss: 0.5695666860303154
# Epoch 27/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.480662966390019 		 Validation Loss: 0.40535820259348204
# Epoch 28/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.367198729320713 		 Validation Loss: 0.4186775050247493
# Epoch 29/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.3771535856244355 		 Validation Loss: 0.46048487892941287
# Epoch 30/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.266912050869154 		 Validation Loss: 0.4145717896197153
# Epoch 31/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.3505973594830087 		 Validation Loss: 0.4478800810225632
# Epoch 32/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1762333865398946 		 Validation Loss: 0.42586605655758275
# Epoch 33/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.326090527293475 		 Validation Loss: 0.3643736853061811
# Epoch 34/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.35528373191862 		 Validation Loss: 0.4509189136164344
# Epoch 35/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1439478093272317 		 Validation Loss: 0.35998101637739205
# Epoch 36/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9589195277379907 		 Validation Loss: 0.42750119539382664
# Epoch 37/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.049299129811318 		 Validation Loss: 0.43993248474662716
# Epoch 38/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0446087432944258 		 Validation Loss: 0.36357828011007415
# Epoch 39/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.068948547639277 		 Validation Loss: 0.5041252360071825
# Epoch 40/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1496914235632056 		 Validation Loss: 0.39087068062761554
# Epoch 41/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8469326428907074 		 Validation Loss: 0.3422311404719949
# Epoch 42/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.930548931107573 		 Validation Loss: 0.41639177485004714
# Epoch 43/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0607186786668454 		 Validation Loss: 0.4232726811795779
# Epoch 44/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.922701952736015 		 Validation Loss: 0.36311066417914367
# Epoch 45/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8298619936179856 		 Validation Loss: 0.3724033677059671
# Epoch 46/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8711677049489126 		 Validation Loss: 0.3975807282587756
# Epoch 47/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.791687982885734 		 Validation Loss: 0.46654958771946636
# Epoch 48/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7527516972597526 		 Validation Loss: 0.42043616687474045
# Epoch 49/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.840451555326581 		 Validation Loss: 0.42684587091207504
# Epoch 50/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6439616184114763 		 Validation Loss: 0.5300162492886834
# Epoch 51/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7989718435413165 		 Validation Loss: 0.442777160231186
# Epoch 52/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7160895074434255 		 Validation Loss: 0.35784309284518595
# Epoch 53/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.555704941406198 		 Validation Loss: 0.32602338873497816
# Epoch 54/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6300746793656244 		 Validation Loss: 0.3393691485018834
# Epoch 55/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5704690392088632 		 Validation Loss: 0.33273733439652814
# Epoch 56/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6383107102921475 		 Validation Loss: 0.5024269460497991
# Epoch 57/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6805293032818513 		 Validation Loss: 0.3415471767682744
# Epoch 58/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5180819383214996 		 Validation Loss: 0.32906236167511216
# Epoch 59/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.603383612130647 		 Validation Loss: 0.3232087155237146
# Epoch 60/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4027992071502882 		 Validation Loss: 0.4593108166819033
# Epoch 61/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4651653386004593 		 Validation Loss: 0.363621948286891
# Epoch 62/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4728737801070446 		 Validation Loss: 0.32688411325216293
# Epoch 63/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.414743664391015 		 Validation Loss: 0.3830963613708382
# Epoch 64/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4078509914486304 		 Validation Loss: 0.3452677785054497
# Epoch 65/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.415247068821412 		 Validation Loss: 0.3409051134696473
# Epoch 66/120
# LR: [0.0001]
# ...
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1943153628026661 		 Validation Loss: 0.28676017402144877
# Epoch 101/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.132197385451392 		 Validation Loss: 0.27441727426712925
# Epoch 102/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1426496966539517 		 Validation Loss: 0.2684250263416249
# Epoch 103/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.169170806893026 		 Validation Loss: 0.2931609825919504
# Epoch 104/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.2016284246321605 		 Validation Loss: 0.297728988180018
# Epoch 105/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0588714661805525 		 Validation Loss: 0.25879945342793415
# Epoch 106/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.034854680866651 		 Validation Loss: 0.2677008135082281
# Epoch 107/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1178083575290183 		 Validation Loss: 0.2629666489994396
# Epoch 108/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0837887869337979 		 Validation Loss: 0.2915291291378114
# Epoch 109/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0472275310641397 		 Validation Loss: 0.2786093194685552
# Epoch 110/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.134391077146258 		 Validation Loss: 0.262670058230667
# Epoch 111/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0897847906807843 		 Validation Loss: 0.2677540105322133
# Epoch 112/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.039986171192773 		 Validation Loss: 0.25281028490027657
# Epoch 113/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.067292048352892 		 Validation Loss: 0.269871781701627
# Epoch 114/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0365141430545761 		 Validation Loss: 0.2727089255400326
# Epoch 115/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0054636603302283 		 Validation Loss: 0.2701378637600852
# Epoch 116/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 0.9667255595407408 		 Validation Loss: 0.27676503165908484
# Epoch 117/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0388019378499493 		 Validation Loss: 0.27394052307404904
# Epoch 118/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0592037127960636 		 Validation Loss: 0.29857821062045253
# Epoch 119/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.061330833107881 		 Validation Loss: 0.28167253441136814
# Epoch 120/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.029272885993123 		 Validation Loss: 0.30807893877120124
# Finished Training
# lr = 0.0001
# rsquared = 0.982470340718198
# MSE Error = 0.00044694656138434313
# FOLD 4
# --------------------------------
# Epoch 1/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 39.97552125415076 		 Validation Loss: 5.5855371498543285
# Epoch 2/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 8.636132453770742 		 Validation Loss: 1.45039889410786
# Epoch 3/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 4.461814198804938 		 Validation Loss: 1.6179142863206242
# Epoch 4/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.8223384615519773 		 Validation Loss: 0.7707863613639189
# Epoch 5/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.4798465332259303 		 Validation Loss: 0.8038217801114788
# Epoch 6/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.548291854398406 		 Validation Loss: 0.7270522869151571
# Epoch 7/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.318873580707156 		 Validation Loss: 0.9448051323061404
# Epoch 8/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.075818567496279 		 Validation Loss: 0.5802843971582858
# Epoch 9/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.220300742789455 		 Validation Loss: 0.640282869581943
# Epoch 10/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.107408482419408 		 Validation Loss: 0.5905336533551631
# Epoch 11/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.1471147529942836 		 Validation Loss: 0.5922006071423707
# Epoch 12/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.9244265719924285 		 Validation Loss: 0.5581905934149805
# Epoch 13/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.701517579591145 		 Validation Loss: 0.5436722483971844
# Epoch 14/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.9579698986819256 		 Validation Loss: 0.4968405353796223
# Epoch 15/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.847047147138611 		 Validation Loss: 0.5421260692908064
# Epoch 16/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.8190302308648825 		 Validation Loss: 0.6055708979458913
# Epoch 17/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.926350483265908 		 Validation Loss: 0.5814521989744642
# Epoch 18/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 3.044648080902255 		 Validation Loss: 0.5729877208562001
# Epoch 19/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.784535453614333 		 Validation Loss: 0.7813765477875004
# Epoch 20/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.725810130329236 		 Validation Loss: 0.49707047884231026
# Epoch 21/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.7662325666245557 		 Validation Loss: 0.6404812245265298
# Epoch 22/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.5438261901878794 		 Validation Loss: 0.47680097672602406
# Epoch 23/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.5074851130661755 		 Validation Loss: 0.45621868959911493
# Epoch 24/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.736249253477739 		 Validation Loss: 0.47248637149839295
# Epoch 25/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.6963021894511967 		 Validation Loss: 0.46188611638448807
# Epoch 26/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.4302832455090853 		 Validation Loss: 0.49189992913085484
# Epoch 27/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.23905778190364 		 Validation Loss: 0.4501903903387163
# Epoch 28/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.493232127521997 		 Validation Loss: 0.44025517400840053
# Epoch 29/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.2313190445141946 		 Validation Loss: 0.4441436836091073
# Epoch 30/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.4292563272883063 		 Validation Loss: 0.4374957657216684
# Epoch 31/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.356213880945807 		 Validation Loss: 0.4307027969347394
# Epoch 32/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.659936908632517 		 Validation Loss: 0.47145422693827876
# Epoch 33/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.308411935263354 		 Validation Loss: 0.6733917227905729
# Epoch 34/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.5743467164752274 		 Validation Loss: 0.44349263729932514
# Epoch 35/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.18147493250992 		 Validation Loss: 0.5119576965985091
# Epoch 36/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.3455598571378253 		 Validation Loss: 0.4433602577318316
# Epoch 37/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.3962559900853946 		 Validation Loss: 0.42785371807606326
# Epoch 38/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9645822393181531 		 Validation Loss: 0.4142131201275017
# Epoch 39/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.241360187449533 		 Validation Loss: 0.4495248399350954
# Epoch 40/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.1351053562501203 		 Validation Loss: 0.5432041634036147
# Epoch 41/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.0944245704652174 		 Validation Loss: 0.43431536189239955
# Epoch 42/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.951903605752665 		 Validation Loss: 0.44900168097861437
# Epoch 43/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.049442507326603 		 Validation Loss: 0.45585137168350426
# Epoch 44/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7796728800496329 		 Validation Loss: 0.4725809649604818
# Epoch 45/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.9455823495012263 		 Validation Loss: 0.3948068624443334
# Epoch 46/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.778963489619934 		 Validation Loss: 0.37950507357068686
# Epoch 47/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 2.069185225131071 		 Validation Loss: 0.41330833287666674
# Epoch 48/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.7053806653813175 		 Validation Loss: 0.42190694509317045
# Epoch 49/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.8068644171580672 		 Validation Loss: 0.38624467878885893
# Epoch 50/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6188547756198957 		 Validation Loss: 0.446281331712785
# Epoch 51/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.613548134656056 		 Validation Loss: 0.40323335426333157
# Epoch 52/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5880607798614579 		 Validation Loss: 0.35398396217952605
# Epoch 53/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6084525187540313 		 Validation Loss: 0.3714424410591955
# Epoch 54/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6423437111079693 		 Validation Loss: 0.36137415970797127
# Epoch 55/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6560195409895286 		 Validation Loss: 0.4349044222870599
# Epoch 56/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.6055929530411959 		 Validation Loss: 0.3536592141684631
# Epoch 57/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4565350082905397 		 Validation Loss: 0.38229912778605585
# Epoch 58/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4636450877980045 		 Validation Loss: 0.338359711529768
# Epoch 59/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5160243959044633 		 Validation Loss: 0.35529100554792775
# Epoch 60/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3935881023011778 		 Validation Loss: 0.3808988037964572
# Epoch 61/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.476751502522308 		 Validation Loss: 0.35616080835461617
# Epoch 62/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4932479217810475 		 Validation Loss: 0.3588604873613171
# Epoch 63/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4235215389534184 		 Validation Loss: 0.3469531707789587
# Epoch 64/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.4516000470713428 		 Validation Loss: 0.3772136185966108
# Epoch 65/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3831027717046116 		 Validation Loss: 0.32633983165673586
# Epoch 66/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.401898378384826 		 Validation Loss: 0.4824535054681094
# Epoch 67/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.53669479392145 		 Validation Loss: 0.339369428222594
# Epoch 68/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.5033453439726778 		 Validation Loss: 0.3711869751467653
# Epoch 69/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3707955933945335 		 Validation Loss: 0.3198857121169567
# Epoch 70/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3463778759798277 		 Validation Loss: 0.40051000573388906
# Epoch 71/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3172137406857118 		 Validation Loss: 0.31505971887837286
# Epoch 72/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2887080878262287 		 Validation Loss: 0.3436997355083409
# Epoch 73/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3849464203028574 		 Validation Loss: 0.5527910926257786
# Epoch 74/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2809407544200835 		 Validation Loss: 0.33764736455581756
# Epoch 75/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3382869770993358 		 Validation Loss: 0.40343207274766074
# Epoch 76/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3069810635693695 		 Validation Loss: 0.3174814180997403
# Epoch 77/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3726803881480643 		 Validation Loss: 0.3606370379338446
# Epoch 78/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2531978118273874 		 Validation Loss: 0.33246916285513534
# Epoch 79/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.222536642063895 		 Validation Loss: 0.2907156492380992
# Epoch 80/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2529208381943728 		 Validation Loss: 0.3295348110082357
# Epoch 81/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2828110874347065 		 Validation Loss: 0.3087981617807046
# Epoch 82/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.3217405173927546 		 Validation Loss: 0.36542601988691353
# Epoch 83/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2932384189056314 		 Validation Loss: 0.34362175801525946
# Epoch 84/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2027783785015345 		 Validation Loss: 0.33512729276781494
# Epoch 85/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.229407455853146 		 Validation Loss: 0.29512222694314044
# Epoch 86/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1799346670184447 		 Validation Loss: 0.3084525470824345
# Epoch 87/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2105797711435868 		 Validation Loss: 0.2919673504226882
# Epoch 88/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1436196614218794 		 Validation Loss: 0.35324641406212165
# Epoch 89/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2842349938886322 		 Validation Loss: 0.27962359109812457
# Epoch 90/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1313999085484638 		 Validation Loss: 0.3077051378786564
# Epoch 91/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1565043180776031 		 Validation Loss: 0.33878544661337917
# Epoch 92/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1273942244360629 		 Validation Loss: 0.4152923824832491
# Epoch 93/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1852152510343685 		 Validation Loss: 0.30590218167913996
# Epoch 94/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2327945815885197 		 Validation Loss: 0.3002381867364697
# Epoch 95/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.175739337042298 		 Validation Loss: 0.3274753867122142
# Epoch 96/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1019265126922857 		 Validation Loss: 0.29477348814353993
# Epoch 97/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.2258474340905314 		 Validation Loss: 0.356890215659919
# Epoch 98/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.181047601868277 		 Validation Loss: 0.31092082494464907
# Epoch 99/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.1309514960840992 		 Validation Loss: 0.27435473534885957
# Epoch 100/120
# LR: [0.0001]
# ----------
# 	 Training Loss: 1.123794364095058 		 Validation Loss: 0.2583305775795294
# Epoch 101/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.133138637908775 		 Validation Loss: 0.2691637017642674
# Epoch 102/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1262259242813224 		 Validation Loss: 0.3241275281280927
# Epoch 103/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.210844651998385 		 Validation Loss: 0.32006038741573045
# Epoch 104/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1001858695855606 		 Validation Loss: 0.2612069821714059
# Epoch 105/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0905018487702245 		 Validation Loss: 0.2871507844361274
# Epoch 106/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.117852509021759 		 Validation Loss: 0.2811498053209937
# Epoch 107/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1135582211629853 		 Validation Loss: 0.26253095698421414
# Epoch 108/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1310914808317372 		 Validation Loss: 0.31546038705045765
# Epoch 109/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0555135165138736 		 Validation Loss: 0.2738714812161482
# Epoch 110/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0697093849758739 		 Validation Loss: 0.42038678928561835
# Epoch 111/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1148803057553975 		 Validation Loss: 0.3522338757858328
# Epoch 112/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0552462051703555 		 Validation Loss: 0.33317204054606997
# Epoch 113/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.011277862338592 		 Validation Loss: 0.26387547648957244
# Epoch 114/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.1139876126595165 		 Validation Loss: 0.2673941269597929
# Epoch 115/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.022137683370839 		 Validation Loss: 0.26157351190467243
# Epoch 116/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0269936722419832 		 Validation Loss: 0.24822550032125867
# Epoch 117/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.055829666150005 		 Validation Loss: 0.26030886537678866
# Epoch 118/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0660903881425443 		 Validation Loss: 0.2619072870229897
# Epoch 119/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0636121015185895 		 Validation Loss: 0.31583243090173474
# Epoch 120/120
# LR: [8e-05]
# ----------
# 	 Training Loss: 1.0579360494309145 		 Validation Loss: 0.2524874291342238
# Finished Training
# lr = 0.0001
# rsquared = 0.9874963791830597
# MSE Error = 0.0003491522174724344
